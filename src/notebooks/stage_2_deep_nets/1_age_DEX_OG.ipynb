# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## 1. Setup

# %%
# NECESSARY IMPORTS
import pandas as pd
import numpy  as np

from keras.models     import Sequential
from keras.layers     import Dense, Dropout, Activation, Flatten, advanced_activations
from keras.layers     import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD, Adam

from keras.utils.data_utils import get_file
from keras import initializations
from keras.callbacks import ModelCheckpoint
import keras.backend     as K
import matplotlib.pyplot as plt

from pandas                     import Series
from scipy.misc                 import imresize
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image  import (ImageDataGenerator, 
                                        array_to_img,
                                        img_to_array,
                                        load_img)
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
# Out:
# Using TensorFlow backend.

# %%
# VGG16-Face Pre-trained weights download links
TF_WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5'
VGG16_LOCAL_W   = "'vgg16_weights_tf_dim_ordering_tf_kernels.h5'"

# %%
# %matplotlib inline

# %%
# Ensure reproducibility
np.random.seed(0)

# %%
# Path constants
DATA_TEMPLATE     = "./../../data/"
ADIENCE_META_P    = DATA_TEMPLATE + "adience/meta"
ADIENCE_RAW_P     = DATA_TEMPLATE + "adience/keras_format"
ADIENCE_AGE_P     = ADIENCE_RAW_P + "/age"
ADIENCE_GEN_P     = ADIENCE_RAW_P + "/gender"
IMG_PATH          = DATA_TEMPLATE + "wiki/%s"

WIKI_META_P       = DATA_TEMPLATE + "wiki_meta"
MODEL_TEMPLATE    = "./models/%s"
WEIGHTS_TEMPLATE  = "./weights/%s"
GRAPHS_TEMPLATE   = "./graphs/%s"
HISTORY_TEMPLATE   = "./histories/%s"

# %%
# Independent constants
MODEL_NAME = "1_age_DEX_OG"
INITIALIZATION = 'normal'
LOSS           = "categorical_crossentropy"
OPTIMIZER      = SGD(lr=1e-3, momentum=0.9, decay=5e-4)
BATCH_SIZE     = 32


PIC_NAME     = GRAPHS_TEMPLATE % (MODEL_NAME + ".png")
PIC_NAME_FINETUNING = GRAPHS_TEMPLATE % (MODEL_NAME + "_finetuning_.png")
WEIGHTS_NAME = WEIGHTS_TEMPLATE % (MODEL_NAME + ".h5")
TRA_HISTORY_NAME = HISTORY_TEMPLATE % (MODEL_NAME + "_train_"+".npy")
VAL_HISTORY_NAME = HISTORY_TEMPLATE % (MODEL_NAME + "_valid_"+".npy")


WEIGHTS_NAME_FINETUNING = WEIGHTS_TEMPLATE % (MODEL_NAME + "_finetuning_.h5")
TRA_HISTORY_NAME_FINETUNING = HISTORY_TEMPLATE % (MODEL_NAME + "_train_"+"_finetuning_.npy")
VAL_HISTORY_NAME_FINETUNING = HISTORY_TEMPLATE % (MODEL_NAME + "_valid_"+"_finetuning_.npy")

IMG_WIDTH  = 227
IMG_HEIGHT = 227


ADIENCE_FULL = ["idx","user_id","face_id","original_image","gender","age","img_path","keras_path"]
ADIENCE_HEADER = ["user_id","face_id","original_image","gender","age","img_path","keras_path"]
WIKI_HEADER    = ["full_path","age","gender"]

NUM_EPOCHS  = 1500
NUM_EPOCHS2 = 500


BEST_CHECKPOINT = MODEL_NAME + ".weights.{epoch:02d}-{val_loss:.2f}.hdf5"
BEST_CHECKPOINT_FINE = MODEL_NAME + "FINETUNE.weights.{epoch:02d}-{val_loss:.2f}.hdf5"

# %%
callback1 = ModelCheckpoint(BEST_CHECKPOINT, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=10)

# %%
callback2 = ModelCheckpoint(BEST_CHECKPOINT_FINE, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=10)

# %%
# Dependent constants
IMG_DIMS = (IMG_WIDTH, IMG_HEIGHT)
MODEL_W  = MODEL_NAME + ".h5"
MODEL_P  = MODEL_NAME + ".txt"

# %% [markdown]
# ## 2. Loading metadata

# %% [markdown]
# ### Adience

# %%
gender_train_path = ADIENCE_META_P + "/gender_train_0.csv"
gender_valid_path = ADIENCE_META_P + "/gender_valid_0.csv"
gender_train = pd.read_csv(filepath_or_buffer =gender_train_path)
gender_valid = pd.read_csv(filepath_or_buffer =gender_valid_path)

gender_train = gender_train[ADIENCE_HEADER]
gender_valid = gender_valid[ADIENCE_HEADER]

# %%
age_train_path = ADIENCE_META_P + "/age_train_0.csv"
age_valid_path = ADIENCE_META_P + "/age_valid_0.csv"
age_train = pd.read_csv(filepath_or_buffer =gender_train_path)
age_valid = pd.read_csv(filepath_or_buffer =gender_valid_path)

age_train = age_train[ADIENCE_HEADER]
age_valid = age_valid[ADIENCE_HEADER]

# %% [markdown]
# ### Wiki

# %%
w_gender_train_path = WIKI_META_P + "/gender/train_1.csv"
w_gender_valid_path = WIKI_META_P + "/gender/valid_1.csv"

w_gender_train = pd.read_csv(filepath_or_buffer =w_gender_train_path)
w_gender_valid = pd.read_csv(filepath_or_buffer =w_gender_valid_path)

w_gender_train = w_gender_train[WIKI_HEADER]
w_gender_valid = w_gender_valid[WIKI_HEADER]

# %%
w_age_train_path = WIKI_META_P + "/gender/train_1.csv"
w_age_valid_path = WIKI_META_P + "/gender/valid_1.csv"
w_age_train = pd.read_csv(filepath_or_buffer =w_age_train_path)
w_age_valid = pd.read_csv(filepath_or_buffer =w_age_valid_path)

w_age_train = w_age_train[WIKI_HEADER]
w_age_valid = w_age_valid[WIKI_HEADER]

# %% [markdown]
# ### SHALLOW-ONLY TASK: Fix age ranges

# %%
def fix_age_ranges(age):
    if age < 4:
        return "(0, 2)"
    if age < 8:
        return "(4, 6)"
    if age < 15:
        return "(8, 13)"
    if age < 25:
        return "(15, 20)"
    if age < 38:
        return "(25, 32)"
    if age < 48:
        return "(38, 43)"
    if age < 60:
        return "(48, 53)"
    return "(60-100)"

w_age_train["age"]    = w_age_train["age"].apply(lambda x: fix_age_ranges(x))
w_age_valid["age"]    = w_age_valid["age"].apply(lambda x: fix_age_ranges(x))
w_gender_train["age"] = w_gender_train["age"].apply(lambda x: fix_age_ranges(x))
w_gender_valid["age"] = w_gender_valid["age"].apply(lambda x: fix_age_ranges(x))

# %% [markdown]
# ## 3. Data pipeline

# %% [markdown]
# ### 3.1 Adience

# %%
adience_train_aug = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        rescale=1./255,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
adience_valid_aug = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ### Train

# %%
ADIENCE_GENDER_TRAIN_P = ADIENCE_GEN_P + "/train/1"
adience_gender_train_gen = adience_train_aug.flow_from_directory(
    ADIENCE_GENDER_TRAIN_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 10505 images belonging to 2 classes.

# %%
ADIENCE_AGE_TRAIN_P = ADIENCE_AGE_P + "/train/1"
adience_age_train_gen = adience_train_aug.flow_from_directory(
    ADIENCE_AGE_TRAIN_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 10505 images belonging to 8 classes.

# %% [markdown]
# ### Validation

# %%
ADIENCE_GENDER_VALID_P = ADIENCE_GEN_P + "/valid/1"
adience_gender_valid_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_GENDER_VALID_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3502 images belonging to 2 classes.

# %%
ADIENCE_AGE_VALID_P = ADIENCE_AGE_P + "/valid/1"
adience_age_valid_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_AGE_VALID_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3502 images belonging to 8 classes.

# %% [markdown]
# ### Test

# %%
ADIENCE_GENDER_TEST_P = ADIENCE_GEN_P + "/test/"
adience_gender_test_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_GENDER_TEST_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3445 images belonging to 2 classes.

# %%
ADIENCE_AGE_TEST_P = ADIENCE_AGE_P + "/test/"
adience_age_test_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_AGE_TEST_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3445 images belonging to 8 classes.

# %% [markdown]
# ### 3.2 Wiki

# %%
true_path = lambda x: IMG_PATH % x
w_age_train["full_path"]    = w_age_train["full_path"].apply(lambda x: true_path(x))
w_gender_train["full_path"] = w_gender_train["full_path"].apply(lambda x: true_path(x))
w_age_valid["full_path"]    = w_age_valid["full_path"].apply(lambda x: true_path(x))
w_gender_valid["full_path"] = w_gender_valid["full_path"].apply(lambda x: true_path(x))

# %%
def get_image(x):
    try:
        val = img_to_array(imresize(load_img(x),IMG_DIMS))
    except:
        val = "ERR"
    return val

# %%
# Data generator
def generate_test(df, batch_size, target_feature):
    start, end = 0, batch_size
    while True:
        while end < len(dfs.shape[0]):
            ages_h = list(pd.get_dummies(data["age"]).columns.values)
            ages   = pd.get_dummies(data["age"])
            data[ages_h] = ages

            sample = data[start:end]
            start += batch_size
            end   += batch_size

            X         = pd.DataFrame(sample["full_path"].apply(lambda x:get_image(x)))
            good_rows = X["full_path"] != "ERR"
            X         = X[good_rows]
            X.reset_index(inplace=True)
            X = X["full_path"].apply(lambda x: x.reshape((1,)+ x.shape))
            X = np.vstack(X)
            #X = model.predict(X, X.shape[0])

            Y = sample[good_rows]
            if target_feature == "age":
                Y = Y[ages_h].as_matrix()
            else:
                Y = Y[target_feature].as_matrix()
            yield (X,Y)

# %%
# Data generator
def generate_data(df, batch_size, target_feature):
    start, end = 0, batch_size
    while True:
        data   = df.sample(frac=1).reset_index(drop=True)
        ages_h = list(pd.get_dummies(data["age"]).columns.values)
        ages   = pd.get_dummies(data["age"])
        data[ages_h] = ages
        
        sample = data[start:end]
        
        X         = pd.DataFrame(sample["full_path"].apply(lambda x:get_image(x)))
        good_rows = X["full_path"] != "ERR"
        X         = X[good_rows]
        X.reset_index(inplace=True)
        X = X["full_path"].apply(lambda x: x.reshape((1,)+ x.shape))
        X = np.vstack(X)
        #X = model.predict(X, X.shape[0])
        
        Y = sample[good_rows]
        if target_feature == "age":
            Y = Y[ages_h].as_matrix()
        else:
            Y = Y[target_feature].as_matrix()
        yield (X,Y)

# %%
w_age_train_gen = generate_data(w_age_train, BATCH_SIZE, "age")
w_age_valid_gen = generate_data(w_age_valid, BATCH_SIZE, "age")
w_gender_train_gen = generate_data(w_gender_train, BATCH_SIZE, "gender")
w_gender_valid_gen = generate_data(w_gender_valid, BATCH_SIZE, "gender")

# %%
from keras.engine.topology import Layer
class LRN2D(Layer):
    """
    This code is adapted from pylearn2.
    License at: https://github.com/lisa-lab/pylearn2/blob/master/LICENSE.txt
    """

    def __init__(self, alpha=1e-4, k=2, beta=0.75, n=5):
        if n % 2 == 0:
            raise NotImplementedError("LRN2D only works with odd n. n provided: " + str(n))
        super(LRN2D, self).__init__()
        self.alpha = alpha
        self.k = k
        self.beta = beta
        self.n = n

    def get_output(self, train):
        X = self.get_input(train)
        b, ch, r, c = X.shape
        half_n = self.n // 2
        input_sqr = T.sqr(X)
        extra_channels = T.alloc(0., b, ch + 2*half_n, r, c)
        input_sqr = T.set_subtensor(extra_channels[:, half_n:half_n+ch, :, :], input_sqr)
        scale = self.k
        for i in range(self.n):
            scale += self.alpha * input_sqr[:, i:i+ch, :, :]
        scale = scale ** self.beta
        return X / scale

    def get_config(self):
        return {"name": self.__class__.__name__,
                "alpha": self.alpha,
                "k": self.k,
                "beta": self.beta,
"n": self.n}

# %% [markdown]
# ## 4. Building the model

# %%
# VGG16 network
model = Sequential()
model.add(ZeroPadding2D((1, 1), input_shape=(IMG_WIDTH, IMG_HEIGHT,3)))

model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_2'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_2'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_2'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_2'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_2'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(Flatten())
model.add(Dense(4096, activation='relu', name="fc_1"))
model.add(Dense(4096, activation='relu', name="fc_w"))
model.add(Dense(1000, activation='softmax',  name="predictions"))

# %%
# Obtain VGG16-Face weights
weights_path = get_file(VGG16_LOCAL_W,TF_WEIGHTS_PATH, cache_subdir='models')

# %%
# Loading VGG16-Face weights to VGG16 network
model.load_weights(weights_path)

# %%
from keras import backend as K

def my_init(shape, name=None):
    return K.variable(np.reshape(np.arange(0, shape[0], 1), (101,1)), name=name)

# %%
model.layers.pop()
model.add(Dense(8,activation='softmax'))

# %%
#layer = model.layers[-1]
#layer.trainable = False

for layer in model.layers[:25]:
    layer.trainable = False

# %%
model.compile(loss=LOSS, optimizer=OPTIMIZER, metrics=['accuracy', 'recall', 'precision','f1score'])

# %% [markdown]
# ## 6. Training the model

# %%
history = model.fit_generator(w_age_train_gen, 
                              validation_data=w_age_valid_gen,
                              nb_val_samples=BATCH_SIZE,
                              samples_per_epoch=BATCH_SIZE, 
                              nb_epoch=NUM_EPOCHS)
# Out:
# Epoch 1/1500
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.py:739: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = lib.scalar_compare(x, y, op)
# 32/32 [==============================] - 6s - loss: 2.0820 - acc: 0.1875 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0836 - val_acc: 0.0625 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 2/1500
# 32/32 [==============================] - 1s - loss: 2.0768 - acc: 0.0938 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0763 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 3/1500
# 32/32 [==============================] - 1s - loss: 2.0818 - acc: 0.1250 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0791 - val_acc: 0.1562 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 4/1500
# 32/32 [==============================] - 1s - loss: 2.0814 - acc: 0.0938 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0820 - val_acc: 0.0938 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 5/1500
# 32/32 [==============================] - 1s - loss: 2.0771 - acc: 0.1875 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0756 - val_acc: 0.1875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 6/1500
# 32/32 [==============================] - 1s - loss: 2.0782 - acc: 0.1250 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0799 - val_acc: 0.1250 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 7/1500
# 32/32 [==============================] - 1s - loss: 2.0749 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0774 - val_acc: 0.0625 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 8/1500
# 32/32 [==============================] - 1s - loss: 2.0744 - acc: 0.1562 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0759 - val_acc: 0.1562 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 9/1500
# 32/32 [==============================] - 1s - loss: 2.0763 - acc: 0.0625 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0801 - val_acc: 0.1562 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 10/1500
# 32/32 [==============================] - 1s - loss: 2.0793 - acc: 0.1250 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0783 - val_acc: 0.0938 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 11/1500
# 32/32 [==============================] - 1s - loss: 2.0766 - acc: 0.1875 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0770 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 12/1500
# 32/32 [==============================] - 1s - loss: 2.0737 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0738 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 13/1500
# 32/32 [==============================] - 1s - loss: 2.0761 - acc: 0.2188 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0724 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 14/1500
# 32/32 [==============================] - 1s - loss: 2.0639 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0742 - val_acc: 0.0312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 15/1500
# 32/32 [==============================] - 1s - loss: 2.0733 - acc: 0.1875 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0662 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 16/1500
# 32/32 [==============================] - 1s - loss: 2.0706 - acc: 0.1562 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0652 - val_acc: 0.2500 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 17/1500
# 32/32 [==============================] - 1s - loss: 2.0660 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0677 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 18/1500
# 32/32 [==============================] - 1s - loss: 2.0699 - acc: 0.1562 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0621 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 19/1500
# 32/32 [==============================] - 1s - loss: 2.0657 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0689 - val_acc: 0.1250 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 20/1500
# 32/32 [==============================] - 1s - loss: 2.0557 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0680 - val_acc: 0.1250 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 21/1500
# 32/32 [==============================] - 1s - loss: 2.0663 - acc: 0.1250 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0677 - val_acc: 0.1875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 22/1500
# 32/32 [==============================] - 1s - loss: 2.0640 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0624 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 23/1500
# 32/32 [==============================] - 1s - loss: 2.0682 - acc: 0.2188 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0649 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 24/1500
# 32/32 [==============================] - 1s - loss: 2.0560 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0537 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 25/1500
# 32/32 [==============================] - 1s - loss: 2.0603 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0566 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 26/1500
# 32/32 [==============================] - 1s - loss: 2.0606 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0583 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 27/1500
# 32/32 [==============================] - 1s - loss: 2.0542 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0584 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 28/1500
# 32/32 [==============================] - 1s - loss: 2.0486 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0472 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 29/1500
# 32/32 [==============================] - 1s - loss: 2.0602 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0508 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 30/1500
# 32/32 [==============================] - 1s - loss: 2.0494 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0555 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 31/1500
# 32/32 [==============================] - 1s - loss: 2.0473 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0597 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 32/1500
# 32/32 [==============================] - 1s - loss: 2.0507 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0518 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 33/1500
# 32/32 [==============================] - 1s - loss: 2.0284 - acc: 0.6250 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0461 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 34/1500
# 32/32 [==============================] - 1s - loss: 2.0427 - acc: 0.5312 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0450 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 35/1500
# 32/32 [==============================] - 1s - loss: 2.0472 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0499 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 36/1500
# 32/32 [==============================] - 1s - loss: 2.0425 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0316 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 37/1500
# 32/32 [==============================] - 1s - loss: 2.0324 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0497 - val_acc: 0.2500 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 38/1500
# 32/32 [==============================] - 1s - loss: 2.0490 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0443 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 39/1500
# 32/32 [==============================] - 1s - loss: 2.0351 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0324 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 40/1500
# 32/32 [==============================] - 1s - loss: 2.0327 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0386 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 41/1500
# 32/32 [==============================] - 1s - loss: 2.0307 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0465 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 42/1500
# 32/32 [==============================] - 1s - loss: 2.0414 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0390 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 43/1500
# 32/32 [==============================] - 1s - loss: 2.0474 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0404 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 44/1500
# 32/32 [==============================] - 1s - loss: 2.0395 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0333 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 45/1500
# 32/32 [==============================] - 1s - loss: 2.0340 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0313 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 46/1500
# 32/32 [==============================] - 1s - loss: 2.0185 - acc: 0.5312 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0267 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 47/1500
# 32/32 [==============================] - 1s - loss: 2.0218 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0338 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 48/1500
# 32/32 [==============================] - 1s - loss: 2.0370 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0256 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 49/1500
# 32/32 [==============================] - 1s - loss: 2.0258 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0204 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 50/1500
# 32/32 [==============================] - 1s - loss: 2.0153 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0294 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 51/1500
# 32/32 [==============================] - 1s - loss: 2.0215 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0179 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 52/1500
# 32/32 [==============================] - 1s - loss: 2.0401 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0272 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 53/1500
# 32/32 [==============================] - 1s - loss: 2.0298 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0450 - val_acc: 0.1875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 54/1500
# 32/32 [==============================] - 1s - loss: 2.0167 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0128 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 55/1500
# 32/32 [==============================] - 1s - loss: 2.0185 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0199 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 56/1500
# 32/32 [==============================] - 1s - loss: 2.0158 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0118 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 57/1500
# 32/32 [==============================] - 1s - loss: 2.0241 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0259 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 58/1500
# 32/32 [==============================] - 1s - loss: 1.9961 - acc: 0.5625 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0363 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 59/1500
# 32/32 [==============================] - 1s - loss: 2.0227 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9923 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 60/1500
# 32/32 [==============================] - 1s - loss: 1.9814 - acc: 0.5938 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0099 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 61/1500
# 32/32 [==============================] - 1s - loss: 2.0177 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0152 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 62/1500
# 32/32 [==============================] - 1s - loss: 2.0257 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9962 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 63/1500
# 32/32 [==============================] - 1s - loss: 2.0206 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0056 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 64/1500
# 32/32 [==============================] - 1s - loss: 2.0137 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0114 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 65/1500
# 32/32 [==============================] - 1s - loss: 1.9979 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0092 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 66/1500
# 32/32 [==============================] - 1s - loss: 2.0261 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9821 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 67/1500
# 32/32 [==============================] - 1s - loss: 2.0087 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0080 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 68/1500
# 32/32 [==============================] - 1s - loss: 2.0170 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9959 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 69/1500
# 32/32 [==============================] - 1s - loss: 1.9961 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0201 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 70/1500
# 32/32 [==============================] - 1s - loss: 1.9904 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9933 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 71/1500
# 32/32 [==============================] - 1s - loss: 2.0120 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9700 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 72/1500
# 32/32 [==============================] - 1s - loss: 2.0046 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0151 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 73/1500
# 32/32 [==============================] - 1s - loss: 1.9938 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0215 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 74/1500
# 32/32 [==============================] - 1s - loss: 1.9985 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9905 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 75/1500
# 32/32 [==============================] - 1s - loss: 1.9986 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0050 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 76/1500
# 32/32 [==============================] - 1s - loss: 1.9857 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9871 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 77/1500
# 32/32 [==============================] - 1s - loss: 1.9854 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0061 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 78/1500
# 32/32 [==============================] - 1s - loss: 1.9869 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9766 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 79/1500
# 32/32 [==============================] - 1s - loss: 1.9463 - acc: 0.5938 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9638 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 80/1500
# 32/32 [==============================] - 1s - loss: 1.9555 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9800 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 81/1500
# 32/32 [==============================] - 1s - loss: 1.9977 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9823 - val_acc: 0.1875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 82/1500
# 32/32 [==============================] - 1s - loss: 2.0087 - acc: 0.2188 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9448 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 83/1500
# 32/32 [==============================] - 1s - loss: 1.9827 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9729 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 84/1500
# 32/32 [==============================] - 1s - loss: 1.9648 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9499 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 85/1500
# 32/32 [==============================] - 1s - loss: 1.9604 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9864 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 86/1500
# 32/32 [==============================] - 1s - loss: 1.9823 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9580 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 87/1500
# 32/32 [==============================] - 1s - loss: 1.9633 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9565 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 88/1500
# 32/32 [==============================] - 1s - loss: 1.9887 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9312 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 89/1500
# 32/32 [==============================] - 1s - loss: 1.9438 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0086 - val_acc: 0.1875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 90/1500
# 32/32 [==============================] - 1s - loss: 1.9495 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9289 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 91/1500
# 32/32 [==============================] - 1s - loss: 1.9392 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9749 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 92/1500
# 32/32 [==============================] - 1s - loss: 1.9350 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9798 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 93/1500
# 32/32 [==============================] - 1s - loss: 1.9756 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9167 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 94/1500
# 32/32 [==============================] - 1s - loss: 1.9600 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9702 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 95/1500
# 32/32 [==============================] - 1s - loss: 1.9245 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9187 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 96/1500
# 32/32 [==============================] - 1s - loss: 1.9423 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9513 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 97/1500
# 32/32 [==============================] - 1s - loss: 1.9787 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0058 - val_acc: 0.1875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 98/1500
# 32/32 [==============================] - 1s - loss: 1.9790 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9052 - val_acc: 0.5625 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 99/1500
# 32/32 [==============================] - 1s - loss: 1.9191 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 2.0189 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 100/1500
# 32/32 [==============================] - 1s - loss: 1.9505 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9537 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 101/1500
# 32/32 [==============================] - 1s - loss: 1.9773 - acc: 0.2188 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9622 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 102/1500
# 32/32 [==============================] - 1s - loss: 1.9176 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9886 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 103/1500
# 32/32 [==============================] - 1s - loss: 1.9541 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9294 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 104/1500
# 32/32 [==============================] - 1s - loss: 1.9439 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9539 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 105/1500
# 32/32 [==============================] - 1s - loss: 1.9485 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9207 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 106/1500
# 32/32 [==============================] - 1s - loss: 1.9666 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9238 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 107/1500
# 32/32 [==============================] - 1s - loss: 1.9335 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9001 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 108/1500
# 32/32 [==============================] - 1s - loss: 1.9059 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9190 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 109/1500
# 32/32 [==============================] - 1s - loss: 1.9450 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9249 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 110/1500
# 32/32 [==============================] - 1s - loss: 1.9459 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9898 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 111/1500
# 32/32 [==============================] - 1s - loss: 1.8944 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8865 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 112/1500
# 32/32 [==============================] - 1s - loss: 1.9340 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9361 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 113/1500
# 32/32 [==============================] - 1s - loss: 1.9265 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9256 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 114/1500
# 32/32 [==============================] - 1s - loss: 1.9575 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9875 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 115/1500
# 32/32 [==============================] - 1s - loss: 1.8822 - acc: 0.5938 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9322 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 116/1500
# 32/32 [==============================] - 1s - loss: 1.9140 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8869 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 117/1500
# 32/32 [==============================] - 1s - loss: 1.9195 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9003 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 118/1500
# 32/32 [==============================] - 1s - loss: 1.9143 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9407 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 119/1500
# 32/32 [==============================] - 1s - loss: 1.9829 - acc: 0.2188 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8837 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 120/1500
# 32/32 [==============================] - 1s - loss: 1.8939 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8939 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 121/1500
# 32/32 [==============================] - 1s - loss: 1.9206 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8961 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 122/1500
# 32/32 [==============================] - 1s - loss: 1.9256 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8558 - val_acc: 0.5625 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 123/1500
# 32/32 [==============================] - 1s - loss: 1.9563 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8540 - val_acc: 0.5938 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 124/1500
# 32/32 [==============================] - 1s - loss: 1.8483 - acc: 0.5938 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9181 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 125/1500
# 32/32 [==============================] - 1s - loss: 1.9238 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9162 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 126/1500
# 32/32 [==============================] - 1s - loss: 1.8875 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8767 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 127/1500
# 32/32 [==============================] - 1s - loss: 1.9571 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9194 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 128/1500
# 32/32 [==============================] - 1s - loss: 1.9394 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8906 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 129/1500
# 32/32 [==============================] - 1s - loss: 1.9231 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8843 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 130/1500
# 32/32 [==============================] - 1s - loss: 1.9381 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9001 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 131/1500
# 32/32 [==============================] - 1s - loss: 1.9098 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8950 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 132/1500
# 32/32 [==============================] - 1s - loss: 1.8949 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9025 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 133/1500
# 32/32 [==============================] - 1s - loss: 1.8816 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8857 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 134/1500
# 32/32 [==============================] - 1s - loss: 1.9119 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8745 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 135/1500
# 32/32 [==============================] - 1s - loss: 1.9574 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9081 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 136/1500
# 32/32 [==============================] - 1s - loss: 1.9437 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8781 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 137/1500
# 32/32 [==============================] - 1s - loss: 1.9111 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9041 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 138/1500
# 32/32 [==============================] - 1s - loss: 1.9020 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8889 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 139/1500
# 32/32 [==============================] - 1s - loss: 1.8635 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8770 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 140/1500
# 32/32 [==============================] - 1s - loss: 1.8498 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8918 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 141/1500
# 32/32 [==============================] - 1s - loss: 1.9159 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8591 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 142/1500
# 32/32 [==============================] - 1s - loss: 1.8686 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9120 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 143/1500
# 32/32 [==============================] - 1s - loss: 1.9059 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8823 - val_acc: 0.2500 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 144/1500
# 32/32 [==============================] - 1s - loss: 1.8754 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9070 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 145/1500
# 32/32 [==============================] - 1s - loss: 1.8744 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8379 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 146/1500
# 32/32 [==============================] - 1s - loss: 1.9344 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8514 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 147/1500
# 32/32 [==============================] - 1s - loss: 1.9259 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8901 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 148/1500
# 32/32 [==============================] - 1s - loss: 1.8907 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9239 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 149/1500
# 32/32 [==============================] - 1s - loss: 1.9095 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8938 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 150/1500
# 32/32 [==============================] - 1s - loss: 1.8982 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8559 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 151/1500
# 32/32 [==============================] - 1s - loss: 1.8550 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8776 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 152/1500
# 32/32 [==============================] - 1s - loss: 1.8566 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9369 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 153/1500
# 32/32 [==============================] - 1s - loss: 1.9470 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8763 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 154/1500
# 32/32 [==============================] - 1s - loss: 1.8692 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9202 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 155/1500
# 32/32 [==============================] - 1s - loss: 1.8695 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8710 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 156/1500
# 32/32 [==============================] - 1s - loss: 1.9117 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8775 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 157/1500
# 32/32 [==============================] - 1s - loss: 1.9464 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8681 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 158/1500
# 32/32 [==============================] - 1s - loss: 1.8290 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8426 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 159/1500
# 32/32 [==============================] - 1s - loss: 1.8845 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8660 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 160/1500
# 32/32 [==============================] - 1s - loss: 1.8682 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8733 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 161/1500
# 32/32 [==============================] - 1s - loss: 1.8598 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8995 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 162/1500
# 32/32 [==============================] - 1s - loss: 1.9170 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9426 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 163/1500
# 32/32 [==============================] - 1s - loss: 1.8224 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.9396 - val_acc: 0.2500 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 164/1500
# 32/32 [==============================] - 1s - loss: 1.9305 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8938 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 165/1500
# 32/32 [==============================] - 1s - loss: 1.7430 - acc: 0.6875 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8697 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 166/1500
# 32/32 [==============================] - 1s - loss: 1.9177 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8643 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 167/1500
# 32/32 [==============================] - 1s - loss: 1.8368 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8432 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 168/1500
# 32/32 [==============================] - 1s - loss: 1.8758 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8395 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 169/1500
# 32/32 [==============================] - 1s - loss: 1.9105 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8530 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 170/1500
# 32/32 [==============================] - 1s - loss: 1.8609 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.7943 - val_acc: 0.5938 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 171/1500
# 32/32 [==============================] - 1s - loss: 1.9003 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8365 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 172/1500
# 32/32 [==============================] - 1s - loss: 1.8525 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8779 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 173/1500
# 32/32 [==============================] - 1s - loss: 1.9445 - acc: 0.2188 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8463 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 174/1500
# 32/32 [==============================] - 1s - loss: 1.7828 - acc: 0.5312 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8686 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 175/1500
# 32/32 [==============================] - 1s - loss: 1.8260 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.8667 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 176/1500
# ...
# Epoch 1443/1500
# 32/32 [==============================] - 1s - loss: 1.3747 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4421 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1444/1500
# 32/32 [==============================] - 1s - loss: 1.6135 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4749 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1445/1500
# 32/32 [==============================] - 1s - loss: 1.5045 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6868 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1446/1500
# 32/32 [==============================] - 1s - loss: 1.5411 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3580 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1447/1500
# 32/32 [==============================] - 1s - loss: 1.4687 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3867 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1448/1500
# 32/32 [==============================] - 1s - loss: 1.4766 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5873 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1449/1500
# 32/32 [==============================] - 1s - loss: 1.4479 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4804 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1450/1500
# 32/32 [==============================] - 1s - loss: 1.4480 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4392 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1451/1500
# 32/32 [==============================] - 1s - loss: 1.4258 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5592 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1452/1500
# 32/32 [==============================] - 1s - loss: 1.3891 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4202 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1453/1500
# 32/32 [==============================] - 1s - loss: 1.4534 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6326 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1454/1500
# 32/32 [==============================] - 1s - loss: 1.3453 - acc: 0.5312 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6264 - val_acc: 0.1875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1455/1500
# 32/32 [==============================] - 1s - loss: 1.4535 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3437 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1456/1500
# 32/32 [==============================] - 1s - loss: 1.3978 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5409 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1457/1500
# 32/32 [==============================] - 1s - loss: 1.4966 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.2636 - val_acc: 0.5938 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1458/1500
# 32/32 [==============================] - 1s - loss: 1.3761 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4994 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1459/1500
# 32/32 [==============================] - 1s - loss: 1.5182 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5122 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1460/1500
# 32/32 [==============================] - 1s - loss: 1.2735 - acc: 0.5312 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6444 - val_acc: 0.1875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1461/1500
# 32/32 [==============================] - 1s - loss: 1.5619 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5152 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1462/1500
# 32/32 [==============================] - 1s - loss: 1.4901 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4963 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1463/1500
# 32/32 [==============================] - 1s - loss: 1.5610 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4591 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1464/1500
# 32/32 [==============================] - 1s - loss: 1.4675 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.2897 - val_acc: 0.5625 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1465/1500
# 32/32 [==============================] - 1s - loss: 1.5593 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4053 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1466/1500
# 32/32 [==============================] - 1s - loss: 1.5243 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6045 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1467/1500
# 32/32 [==============================] - 1s - loss: 1.4395 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4178 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1468/1500
# 32/32 [==============================] - 1s - loss: 1.6352 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3201 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1469/1500
# 32/32 [==============================] - 1s - loss: 1.3521 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5049 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1470/1500
# 32/32 [==============================] - 1s - loss: 1.4324 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.7144 - val_acc: 0.2188 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1471/1500
# 32/32 [==============================] - 1s - loss: 1.6758 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6139 - val_acc: 0.2500 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1472/1500
# 32/32 [==============================] - 1s - loss: 1.5715 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6146 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1473/1500
# 32/32 [==============================] - 1s - loss: 1.3884 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5979 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1474/1500
# 32/32 [==============================] - 1s - loss: 1.4574 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4685 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1475/1500
# 32/32 [==============================] - 1s - loss: 1.5715 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4704 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1476/1500
# 32/32 [==============================] - 1s - loss: 1.4294 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6706 - val_acc: 0.2500 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1477/1500
# 32/32 [==============================] - 1s - loss: 1.5880 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6453 - val_acc: 0.2500 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1478/1500
# 32/32 [==============================] - 1s - loss: 1.5773 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5723 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1479/1500
# 32/32 [==============================] - 1s - loss: 1.4066 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4661 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1480/1500
# 32/32 [==============================] - 1s - loss: 1.6473 - acc: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5878 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1481/1500
# 32/32 [==============================] - 1s - loss: 1.5806 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3566 - val_acc: 0.5625 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1482/1500
# 32/32 [==============================] - 1s - loss: 1.5973 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5551 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1483/1500
# 32/32 [==============================] - 1s - loss: 1.3684 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4663 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1484/1500
# 32/32 [==============================] - 1s - loss: 1.3566 - acc: 0.5312 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5125 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1485/1500
# 32/32 [==============================] - 1s - loss: 1.4840 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3959 - val_acc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1486/1500
# 32/32 [==============================] - 1s - loss: 1.5688 - acc: 0.2812 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4690 - val_acc: 0.4062 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1487/1500
# 32/32 [==============================] - 1s - loss: 1.4957 - acc: 0.3438 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5222 - val_acc: 0.2812 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1488/1500
# 32/32 [==============================] - 1s - loss: 1.4997 - acc: 0.4688 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3599 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1489/1500
# 32/32 [==============================] - 1s - loss: 1.4792 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5060 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1490/1500
# 32/32 [==============================] - 1s - loss: 1.5439 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4651 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1491/1500
# 32/32 [==============================] - 1s - loss: 1.5429 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4715 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1492/1500
# 32/32 [==============================] - 1s - loss: 1.5270 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5004 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1493/1500
# 32/32 [==============================] - 1s - loss: 1.5845 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5605 - val_acc: 0.3438 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1494/1500
# 32/32 [==============================] - 1s - loss: 1.5168 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3434 - val_acc: 0.5312 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1495/1500
# 32/32 [==============================] - 1s - loss: 1.5046 - acc: 0.3125 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3455 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1496/1500
# 32/32 [==============================] - 1s - loss: 1.2194 - acc: 0.6562 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6223 - val_acc: 0.3750 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1497/1500
# 32/32 [==============================] - 1s - loss: 1.4400 - acc: 0.5000 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.5681 - val_acc: 0.3125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1498/1500
# 32/32 [==============================] - 1s - loss: 1.4746 - acc: 0.3750 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.6020 - val_acc: 0.1875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1499/1500
# 32/32 [==============================] - 1s - loss: 1.5356 - acc: 0.4062 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.4477 - val_acc: 0.4688 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 1500/1500
# 32/32 [==============================] - 1s - loss: 1.3723 - acc: 0.4375 - recall: 0.0000e+00 - precision: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 1.3742 - val_acc: 0.4375 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_fmeasure: 0.0000e+00

# %% [markdown]
# ## 7. Evaluating the results

# %%
history.history.keys()
# Out:
# ['acc',
#  'loss',
#  'val_fmeasure',
#  'recall',
#  'precision',
#  'fmeasure',
#  'val_acc',
#  'val_recall',
#  'val_precision',
#  'val_loss']

# %%
train_history = history.history['acc']
valid_history = history.history['val_acc']

# %%
 # Plotting training accuracy and testing accuracy acros epochs
plt.figure(figsize=(20,10))
plt.plot(train_history)
plt.plot(valid_history)
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig(PIC_NAME)

# %%
# Tail-rolling average transform
series_train = Series(train_history)
rolling_train = series_train.rolling(window=100)
rolling_mean_train = rolling_train.mean()

series_valid = Series(valid_history)
rolling_valid = series_valid.rolling(window=100)
rolling_mean_valid = rolling_valid.mean()

# %%
plt.figure(figsize=(20,10))
plt.plot(rolling_mean_train)
plt.plot(rolling_mean_valid)
plt.title('Smoothened training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Saving histories
np.save(TRA_HISTORY_NAME, train_history)
np.save(VAL_HISTORY_NAME, valid_history)

# %%
# saving weights
model.save_weights(WEIGHTS_NAME)

# %% [markdown]
# ### Results on Adience

# %%
model.evaluate_generator(adience_age_test_gen,BATCH_SIZE*400)
# Out:
# [2.0945878032400103, 0.31306990885755925, 0.0, 0.0, 0.0]

# %%
raise EX

# %% [markdown]
# ## Finetuning with Adience

# %%
history = model.fit_generator(adience_gender_train_gen, 
                              validation_data=adience_gender_valid_gen,
                              nb_val_samples=BATCH_SIZE,
                              samples_per_epoch=BATCH_SIZE, 
                              nb_epoch=NUM_EPOCHS2)

# %%
train_history = history.history['acc']
valid_history = history.history['val_acc']

# %%
 # Plotting training accuracy and testing accuracy acros epochs
plt.figure(figsize=(20,10))
plt.plot(train_history)
plt.plot(valid_history)
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig(PIC_NAME_FINETUNING)

# %%
# Tail-rolling average transform
series_train = Series(train_history)
rolling_train = series_train.rolling(window=100)
rolling_mean_train = rolling_train.mean()

series_valid = Series(valid_history)
rolling_valid = series_valid.rolling(window=100)
rolling_mean_valid = rolling_valid.mean()

# %%
plt.figure(figsize=(20,10))
plt.plot(rolling_mean_train)
plt.plot(rolling_mean_valid)
plt.title('Smoothened training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Saving histories
np.save(TRA_HISTORY_NAME_FINETUNING, train_history)
np.save(VAL_HISTORY_NAME_FINETUNING, valid_history)

# %%
# saving weights
model.save_weights(WEIGHTS_NAME_FINETUNING)

# %%
model.evaluate_generator(adience_gender_test_gen,BATCH_SIZE*400)
