# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## 1. Setup

# %%
# NECESSARY IMPORTS
import pandas as pd
import numpy  as np

from keras.models     import Sequential
from keras.layers     import Dense, Dropout, Activation, Flatten, advanced_activations
from keras.layers     import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD, Adam

from keras.utils.data_utils import get_file
from keras import initializations
from keras.callbacks import ModelCheckpoint
import keras.backend     as K
import matplotlib.pyplot as plt

from pandas                     import Series
from scipy.misc                 import imresize
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image  import (ImageDataGenerator, 
                                        array_to_img,
                                        img_to_array,
                                        load_img)
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
# Out:
# Using TensorFlow backend.

# %%
# VGG16-Face Pre-trained weights download links
TF_WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5'
VGG16_LOCAL_W   = "'vgg16_weights_tf_dim_ordering_tf_kernels.h5'"

# %%
# %matplotlib inline

# %%
# Ensure reproducibility
np.random.seed(0)

# %%
# Path constants
DATA_TEMPLATE     = "./../../data/"
ADIENCE_META_P    = DATA_TEMPLATE + "adience/meta"
ADIENCE_RAW_P     = DATA_TEMPLATE + "adience/keras_format"
ADIENCE_AGE_P     = ADIENCE_RAW_P + "/age"
ADIENCE_GEN_P     = ADIENCE_RAW_P + "/gender"
IMG_PATH          = DATA_TEMPLATE + "wiki/%s"

WIKI_META_P       = DATA_TEMPLATE + "wiki_meta"
MODEL_TEMPLATE    = "./models/%s"
WEIGHTS_TEMPLATE  = "./weights/%s"
GRAPHS_TEMPLATE   = "./graphs/%s"
HISTORY_TEMPLATE   = "./histories/%s"

# %%
# Independent constants
MODEL_NAME = "1_age_DEX_OG"
INITIALIZATION = 'normal'
LOSS           = "binary_crossentropy"
OPTIMIZER      = SGD(lr=1e-3, momentum=0.9, decay=5e-4)
BATCH_SIZE     = 32


PIC_NAME     = GRAPHS_TEMPLATE % (MODEL_NAME + ".png")
PIC_NAME_FINETUNING = GRAPHS_TEMPLATE % (MODEL_NAME + "_finetuning_.png")
WEIGHTS_NAME = WEIGHTS_TEMPLATE % (MODEL_NAME + ".h5")
TRA_HISTORY_NAME = HISTORY_TEMPLATE % (MODEL_NAME + "_train_"+".npy")
VAL_HISTORY_NAME = HISTORY_TEMPLATE % (MODEL_NAME + "_valid_"+".npy")


WEIGHTS_NAME_FINETUNING = WEIGHTS_TEMPLATE % (MODEL_NAME + "_finetuning_.h5")
TRA_HISTORY_NAME_FINETUNING = HISTORY_TEMPLATE % (MODEL_NAME + "_train_"+"_finetuning_.npy")
VAL_HISTORY_NAME_FINETUNING = HISTORY_TEMPLATE % (MODEL_NAME + "_valid_"+"_finetuning_.npy")

IMG_WIDTH  = 227
IMG_HEIGHT = 227


ADIENCE_FULL = ["idx","user_id","face_id","original_image","gender","age","img_path","keras_path"]
ADIENCE_HEADER = ["user_id","face_id","original_image","gender","age","img_path","keras_path"]
WIKI_HEADER    = ["full_path","age","gender"]

NUM_EPOCHS  = 1500
NUM_EPOCHS2 = 500


BEST_CHECKPOINT = MODEL_NAME + ".weights.{epoch:02d}-{val_loss:.2f}.hdf5"
BEST_CHECKPOINT_FINE = MODEL_NAME + "FINETUNE.weights.{epoch:02d}-{val_loss:.2f}.hdf5"

# %%
callback1 = ModelCheckpoint(BEST_CHECKPOINT, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=10)

# %%
callback2 = ModelCheckpoint(BEST_CHECKPOINT_FINE, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=10)

# %%
# Dependent constants
IMG_DIMS = (IMG_WIDTH, IMG_HEIGHT)
MODEL_W  = MODEL_NAME + ".h5"
MODEL_P  = MODEL_NAME + ".txt"

# %% [markdown]
# ## 2. Loading metadata

# %% [markdown]
# ### Adience

# %%
gender_train_path = ADIENCE_META_P + "/gender_train_0.csv"
gender_valid_path = ADIENCE_META_P + "/gender_valid_0.csv"
gender_train = pd.read_csv(filepath_or_buffer =gender_train_path)
gender_valid = pd.read_csv(filepath_or_buffer =gender_valid_path)

gender_train = gender_train[ADIENCE_HEADER]
gender_valid = gender_valid[ADIENCE_HEADER]

# %%
age_train_path = ADIENCE_META_P + "/age_train_0.csv"
age_valid_path = ADIENCE_META_P + "/age_valid_0.csv"
age_train = pd.read_csv(filepath_or_buffer =gender_train_path)
age_valid = pd.read_csv(filepath_or_buffer =gender_valid_path)

age_train = age_train[ADIENCE_HEADER]
age_valid = age_valid[ADIENCE_HEADER]

# %% [markdown]
# ### Wiki

# %%
w_gender_train_path = WIKI_META_P + "/gender/train_1.csv"
w_gender_valid_path = WIKI_META_P + "/gender/valid_1.csv"

w_gender_train = pd.read_csv(filepath_or_buffer =w_gender_train_path)
w_gender_valid = pd.read_csv(filepath_or_buffer =w_gender_valid_path)

w_gender_train = w_gender_train[WIKI_HEADER]
w_gender_valid = w_gender_valid[WIKI_HEADER]

# %%
w_age_train_path = WIKI_META_P + "/gender/train_1.csv"
w_age_valid_path = WIKI_META_P + "/gender/valid_1.csv"
w_age_train = pd.read_csv(filepath_or_buffer =w_age_train_path)
w_age_valid = pd.read_csv(filepath_or_buffer =w_age_valid_path)

w_age_train = w_age_train[WIKI_HEADER]
w_age_valid = w_age_valid[WIKI_HEADER]

# %% [markdown]
# ### SHALLOW-ONLY TASK: Fix age ranges

# %%
"""
def fix_age_ranges(age):
    if age < 4:
        return "(0, 2)"
    if age < 8:
        return "(4, 6)"
    if age < 15:
        return "(8, 13)"
    if age < 25:
        return "(15, 20)"
    if age < 38:
        return "(25, 32)"
    if age < 48:
        return "(38, 43)"
    if age < 60:
        return "(48, 53)"
    return "(60-100)"

w_age_train["age"]    = w_age_train["age"].apply(lambda x: fix_age_ranges(x))
w_age_valid["age"]    = w_age_valid["age"].apply(lambda x: fix_age_ranges(x))
w_gender_train["age"] = w_gender_train["age"].apply(lambda x: fix_age_ranges(x))
w_gender_valid["age"] = w_gender_valid["age"].apply(lambda x: fix_age_ranges(x))
"""
# Out:
# '\ndef fix_age_ranges(age):\n    if age < 4:\n        return "(0, 2)"\n    if age < 8:\n        return "(4, 6)"\n    if age < 15:\n        return "(8, 13)"\n    if age < 25:\n        return "(15, 20)"\n    if age < 38:\n        return "(25, 32)"\n    if age < 48:\n        return "(38, 43)"\n    if age < 60:\n        return "(48, 53)"\n    return "(60-100)"\n\nw_age_train["age"]    = w_age_train["age"].apply(lambda x: fix_age_ranges(x))\nw_age_valid["age"]    = w_age_valid["age"].apply(lambda x: fix_age_ranges(x))\nw_gender_train["age"] = w_gender_train["age"].apply(lambda x: fix_age_ranges(x))\nw_gender_valid["age"] = w_gender_valid["age"].apply(lambda x: fix_age_ranges(x))\n'

# %% [markdown]
# ## 3. Data pipeline

# %% [markdown]
# ### 3.1 Adience

# %%
adience_train_aug = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        rescale=1./255,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
adience_valid_aug = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ### Train

# %%
ADIENCE_GENDER_TRAIN_P = ADIENCE_GEN_P + "/train/1"
adience_gender_train_gen = adience_train_aug.flow_from_directory(
    ADIENCE_GENDER_TRAIN_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 10505 images belonging to 2 classes.

# %%
ADIENCE_AGE_TRAIN_P = ADIENCE_AGE_P + "/train/1"
adience_age_train_gen = adience_train_aug.flow_from_directory(
    ADIENCE_AGE_TRAIN_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 10505 images belonging to 8 classes.

# %% [markdown]
# ### Validation

# %%
ADIENCE_GENDER_VALID_P = ADIENCE_GEN_P + "/valid/1"
adience_gender_valid_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_GENDER_VALID_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3502 images belonging to 2 classes.

# %%
ADIENCE_AGE_VALID_P = ADIENCE_AGE_P + "/valid/1"
adience_age_valid_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_AGE_VALID_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3502 images belonging to 8 classes.

# %% [markdown]
# ### Test

# %%
ADIENCE_GENDER_TEST_P = ADIENCE_GEN_P + "/test/"
adience_gender_test_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_GENDER_TEST_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3445 images belonging to 2 classes.

# %%
ADIENCE_AGE_TEST_P = ADIENCE_AGE_P + "/test/"
adience_age_test_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_AGE_TEST_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3445 images belonging to 8 classes.

# %% [markdown]
# ### 3.2 Wiki

# %%
true_path = lambda x: IMG_PATH % x
w_age_train["full_path"]    = w_age_train["full_path"].apply(lambda x: true_path(x))
w_gender_train["full_path"] = w_gender_train["full_path"].apply(lambda x: true_path(x))
w_age_valid["full_path"]    = w_age_valid["full_path"].apply(lambda x: true_path(x))
w_gender_valid["full_path"] = w_gender_valid["full_path"].apply(lambda x: true_path(x))

# %%
def get_image(x):
    try:
        val = img_to_array(imresize(load_img(x),IMG_DIMS))
    except:
        val = "ERR"
    return val

# %%
# Data generator
def generate_test(df, batch_size, target_feature):
    start, end = 0, batch_size
    while True:
        while end < len(dfs.shape[0]):
            ages_h = list(pd.get_dummies(data["age"]).columns.values)
            ages   = pd.get_dummies(data["age"])
            data[ages_h] = ages
            
            
            genders_h = list(pd.get_dummies(data["gender"]).columns.values)
            genders   = pd.get_dummies(data["gender"])
            data[genders_h] = genders

            sample = data[start:end]
            start += batch_size
            end   += batch_size

            X         = pd.DataFrame(sample["full_path"].apply(lambda x:get_image(x)))
            good_rows = X["full_path"] != "ERR"
            X         = X[good_rows]
            X.reset_index(inplace=True)
            X = X["full_path"].apply(lambda x: x.reshape((1,)+ x.shape))
            X = np.vstack(X)
            X /= 255

            #X = model.predict(X, X.shape[0])

            Y = sample[good_rows]
            if target_feature == "age":
                Y = Y[ages_h].as_matrix()
            else:
                Y = pd.get_dummies(Y[genders_h]).as_matrix()
            yield (X,Y)

# %%
# Data generator
def generate_data(df, batch_size, target_feature):
    start, end = 0, batch_size
    while True:
        data   = df.sample(frac=1).reset_index(drop=True)
        ages_h = list(pd.get_dummies(data["age"]).columns.values)
        ages   = pd.get_dummies(data["age"])
        data[ages_h] = ages
        
        genders_h = list(pd.get_dummies(data["gender"]).columns.values)
        genders   = pd.get_dummies(data["gender"])
        data[genders_h] = genders
        
        sample = data[start:end]
        
        X         = pd.DataFrame(sample["full_path"].apply(lambda x:get_image(x)))
        good_rows = X["full_path"] != "ERR"
        X         = X[good_rows]
        X.reset_index(inplace=True)
        X = X["full_path"].apply(lambda x: x.reshape((1,)+ x.shape))
        X = np.vstack(X)
        X /= 255
        #X = model.predict(X, X.shape[0])
        
        Y = sample[good_rows]
        if target_feature == "age":
            Y = Y[ages_h].as_matrix()
        else:
            Y = pd.get_dummies(Y[genders_h]).as_matrix()
        yield (X,Y)

# %%
w_age_train_gen = generate_data(w_age_train, BATCH_SIZE, "age")
w_age_valid_gen = generate_data(w_age_valid, BATCH_SIZE, "age")
w_gender_train_gen = generate_data(w_gender_train, BATCH_SIZE, "gender")
w_gender_valid_gen = generate_data(w_gender_valid, BATCH_SIZE, "gender")

# %%
from keras.engine.topology import Layer
class LRN2D(Layer):
    """
    This code is adapted from pylearn2.
    License at: https://github.com/lisa-lab/pylearn2/blob/master/LICENSE.txt
    """

    def __init__(self, alpha=1e-4, k=2, beta=0.75, n=5):
        if n % 2 == 0:
            raise NotImplementedError("LRN2D only works with odd n. n provided: " + str(n))
        super(LRN2D, self).__init__()
        self.alpha = alpha
        self.k = k
        self.beta = beta
        self.n = n

    def get_output(self, train):
        X = self.get_input(train)
        b, ch, r, c = X.shape
        half_n = self.n // 2
        input_sqr = T.sqr(X)
        extra_channels = T.alloc(0., b, ch + 2*half_n, r, c)
        input_sqr = T.set_subtensor(extra_channels[:, half_n:half_n+ch, :, :], input_sqr)
        scale = self.k
        for i in range(self.n):
            scale += self.alpha * input_sqr[:, i:i+ch, :, :]
        scale = scale ** self.beta
        return X / scale

    def get_config(self):
        return {"name": self.__class__.__name__,
                "alpha": self.alpha,
                "k": self.k,
                "beta": self.beta,
"n": self.n}

# %% [markdown]
# ## 4. Building the model

# %%
# VGG16 network
model = Sequential()
model.add(ZeroPadding2D((1, 1), input_shape=(IMG_WIDTH, IMG_HEIGHT,3)))

model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_2'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_2'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_2'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_2'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_2'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(Flatten())
model.add(Dense(4096, activation='relu', name="fc_1"))
model.add(Dense(4096, activation='relu', name="fc_w"))
model.add(Dense(1000, activation='softmax',  name="predictions"))

# %%
# Obtain VGG16-Face weights
weights_path = get_file(VGG16_LOCAL_W,TF_WEIGHTS_PATH, cache_subdir='models')

# %%
# Loading VGG16-Face weights to VGG16 network
model.load_weights(weights_path)

# %%
from keras import backend as K

def my_init(shape, name=None):
    return K.variable(np.reshape(np.arange(0, shape[0], 1), (101,1)), name=name)

# %%
model.layers.pop()
model.add(Dense(2,activation='softmax'))

# %%
#layer = model.layers[-1]
#layer.trainable = False

for layer in model.layers[:25]:
    layer.trainable = False

# %%
model.compile(loss=LOSS, optimizer=OPTIMIZER, metrics=['accuracy', 'recall', 'precision','f1score'])

# %% [markdown]
# ## 6. Training the model

# %%
history = model.fit_generator(w_gender_train_gen, 
                              validation_data=w_gender_valid_gen,
                              nb_val_samples=BATCH_SIZE,
                              samples_per_epoch=BATCH_SIZE, 
                              nb_epoch=NUM_EPOCHS)
# Out:
# Epoch 1/1500
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.py:739: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = lib.scalar_compare(x, y, op)
# 32/32 [==============================] - 6s - loss: 0.6979 - acc: 0.2188 - recall: 0.2188 - precision: 0.2188 - fmeasure: 0.2187 - val_loss: 0.6985 - val_acc: 0.2500 - val_recall: 0.2500 - val_precision: 0.2500 - val_fmeasure: 0.2500
# Epoch 2/1500
# 32/32 [==============================] - 1s - loss: 0.6968 - acc: 0.3750 - recall: 0.3750 - precision: 0.3750 - fmeasure: 0.3750 - val_loss: 0.6964 - val_acc: 0.3125 - val_recall: 0.3125 - val_precision: 0.3125 - val_fmeasure: 0.3125
# Epoch 3/1500
# 32/32 [==============================] - 1s - loss: 0.6955 - acc: 0.2812 - recall: 0.2812 - precision: 0.2812 - fmeasure: 0.2812 - val_loss: 0.6957 - val_acc: 0.3750 - val_recall: 0.3750 - val_precision: 0.3750 - val_fmeasure: 0.3750
# Epoch 4/1500
# 32/32 [==============================] - 1s - loss: 0.6942 - acc: 0.4375 - recall: 0.4375 - precision: 0.4375 - fmeasure: 0.4375 - val_loss: 0.6940 - val_acc: 0.4062 - val_recall: 0.4062 - val_precision: 0.4062 - val_fmeasure: 0.4062
# Epoch 5/1500
# 32/32 [==============================] - 1s - loss: 0.6933 - acc: 0.4688 - recall: 0.4688 - precision: 0.4688 - fmeasure: 0.4687 - val_loss: 0.6945 - val_acc: 0.4062 - val_recall: 0.4062 - val_precision: 0.4062 - val_fmeasure: 0.4062
# Epoch 6/1500
# 32/32 [==============================] - 1s - loss: 0.6938 - acc: 0.4375 - recall: 0.4375 - precision: 0.4375 - fmeasure: 0.4375 - val_loss: 0.6930 - val_acc: 0.5000 - val_recall: 0.5000 - val_precision: 0.5000 - val_fmeasure: 0.5000
# Epoch 7/1500
# 32/32 [==============================] - 1s - loss: 0.6902 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6916 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 8/1500
# 32/32 [==============================] - 1s - loss: 0.6894 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.6889 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 9/1500
# 32/32 [==============================] - 1s - loss: 0.6896 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6873 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 10/1500
# 32/32 [==============================] - 1s - loss: 0.6879 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6874 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 11/1500
# 32/32 [==============================] - 1s - loss: 0.6863 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.6856 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 12/1500
# 32/32 [==============================] - 1s - loss: 0.6886 - acc: 0.6562 - recall: 0.6562 - precision: 0.6562 - fmeasure: 0.6562 - val_loss: 0.6840 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 13/1500
# 32/32 [==============================] - 1s - loss: 0.6834 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6836 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 14/1500
# 32/32 [==============================] - 1s - loss: 0.6786 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.6837 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 15/1500
# 32/32 [==============================] - 1s - loss: 0.6826 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6818 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 16/1500
# 32/32 [==============================] - 1s - loss: 0.6765 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.6760 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 17/1500
# 32/32 [==============================] - 1s - loss: 0.6818 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6707 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 18/1500
# 32/32 [==============================] - 1s - loss: 0.6748 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.6729 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 19/1500
# 32/32 [==============================] - 1s - loss: 0.6771 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6671 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 20/1500
# 32/32 [==============================] - 1s - loss: 0.6692 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.6768 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 21/1500
# 32/32 [==============================] - 1s - loss: 0.6675 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.6814 - val_acc: 0.6562 - val_recall: 0.6562 - val_precision: 0.6562 - val_fmeasure: 0.6562
# Epoch 22/1500
# 32/32 [==============================] - 1s - loss: 0.6784 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6669 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 23/1500
# 32/32 [==============================] - 1s - loss: 0.6749 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6738 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 24/1500
# 32/32 [==============================] - 1s - loss: 0.6650 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.6636 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 25/1500
# 32/32 [==============================] - 1s - loss: 0.6573 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.6619 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 26/1500
# 32/32 [==============================] - 1s - loss: 0.6749 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6639 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 27/1500
# 32/32 [==============================] - 1s - loss: 0.6432 - acc: 0.9688 - recall: 0.9688 - precision: 0.9688 - fmeasure: 0.9687 - val_loss: 0.6623 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 28/1500
# 32/32 [==============================] - 1s - loss: 0.6664 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6572 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 29/1500
# 32/32 [==============================] - 1s - loss: 0.6610 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6715 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 30/1500
# 32/32 [==============================] - 1s - loss: 0.6555 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.6621 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 31/1500
# 32/32 [==============================] - 1s - loss: 0.6621 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6527 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 32/1500
# 32/32 [==============================] - 1s - loss: 0.6697 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6418 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 33/1500
# 32/32 [==============================] - 1s - loss: 0.6419 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.6399 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 34/1500
# 32/32 [==============================] - 1s - loss: 0.6540 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6387 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 35/1500
# 32/32 [==============================] - 1s - loss: 0.6529 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6569 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 36/1500
# 32/32 [==============================] - 1s - loss: 0.6563 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6397 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 37/1500
# 32/32 [==============================] - 1s - loss: 0.6600 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6546 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 38/1500
# 32/32 [==============================] - 1s - loss: 0.6330 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.6527 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 39/1500
# 32/32 [==============================] - 1s - loss: 0.6477 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6583 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 40/1500
# 32/32 [==============================] - 1s - loss: 0.6578 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6565 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 41/1500
# 32/32 [==============================] - 1s - loss: 0.6504 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6198 - val_acc: 0.9062 - val_recall: 0.9062 - val_precision: 0.9062 - val_fmeasure: 0.9062
# Epoch 42/1500
# 32/32 [==============================] - 1s - loss: 0.6318 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.6431 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 43/1500
# 32/32 [==============================] - 1s - loss: 0.6547 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6480 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 44/1500
# 32/32 [==============================] - 1s - loss: 0.6040 - acc: 0.9688 - recall: 0.9688 - precision: 0.9688 - fmeasure: 0.9687 - val_loss: 0.6336 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 45/1500
# 32/32 [==============================] - 1s - loss: 0.6470 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6386 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 46/1500
# 32/32 [==============================] - 1s - loss: 0.6390 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6040 - val_acc: 0.9375 - val_recall: 0.9375 - val_precision: 0.9375 - val_fmeasure: 0.9375
# Epoch 47/1500
# 32/32 [==============================] - 1s - loss: 0.6720 - acc: 0.6250 - recall: 0.6250 - precision: 0.6250 - fmeasure: 0.6250 - val_loss: 0.6433 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 48/1500
# 32/32 [==============================] - 1s - loss: 0.6011 - acc: 0.9375 - recall: 0.9375 - precision: 0.9375 - fmeasure: 0.9375 - val_loss: 0.6426 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 49/1500
# 32/32 [==============================] - 1s - loss: 0.6128 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.6413 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 50/1500
# 32/32 [==============================] - 1s - loss: 0.6421 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6252 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 51/1500
# 32/32 [==============================] - 1s - loss: 0.6029 - acc: 0.9062 - recall: 0.9062 - precision: 0.9062 - fmeasure: 0.9062 - val_loss: 0.6464 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 52/1500
# 32/32 [==============================] - 1s - loss: 0.6773 - acc: 0.5938 - recall: 0.5938 - precision: 0.5938 - fmeasure: 0.5937 - val_loss: 0.6306 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 53/1500
# 32/32 [==============================] - 1s - loss: 0.6309 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6455 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 54/1500
# 32/32 [==============================] - 1s - loss: 0.6689 - acc: 0.6250 - recall: 0.6250 - precision: 0.6250 - fmeasure: 0.6250 - val_loss: 0.6365 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 55/1500
# 32/32 [==============================] - 1s - loss: 0.6696 - acc: 0.6250 - recall: 0.6250 - precision: 0.6250 - fmeasure: 0.6250 - val_loss: 0.6353 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 56/1500
# 32/32 [==============================] - 1s - loss: 0.6109 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.6431 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 57/1500
# 32/32 [==============================] - 1s - loss: 0.5918 - acc: 0.9062 - recall: 0.9062 - precision: 0.9062 - fmeasure: 0.9062 - val_loss: 0.6432 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 58/1500
# 32/32 [==============================] - 1s - loss: 0.6255 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6591 - val_acc: 0.6562 - val_recall: 0.6562 - val_precision: 0.6562 - val_fmeasure: 0.6562
# Epoch 59/1500
# 32/32 [==============================] - 1s - loss: 0.6509 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6046 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 60/1500
# 32/32 [==============================] - 1s - loss: 0.6048 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.6228 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 61/1500
# 32/32 [==============================] - 1s - loss: 0.5941 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.6479 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 62/1500
# 32/32 [==============================] - 1s - loss: 0.6205 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6007 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 63/1500
# 32/32 [==============================] - 1s - loss: 0.6479 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6370 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 64/1500
# 32/32 [==============================] - 1s - loss: 0.6276 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5982 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 65/1500
# 32/32 [==============================] - 1s - loss: 0.6469 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6068 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 66/1500
# 32/32 [==============================] - 1s - loss: 0.5975 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5953 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 67/1500
# 32/32 [==============================] - 1s - loss: 0.6058 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5926 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 68/1500
# 32/32 [==============================] - 1s - loss: 0.6351 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6563 - val_acc: 0.6562 - val_recall: 0.6562 - val_precision: 0.6562 - val_fmeasure: 0.6562
# Epoch 69/1500
# 32/32 [==============================] - 1s - loss: 0.5824 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.6217 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 70/1500
# 32/32 [==============================] - 1s - loss: 0.6131 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5907 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 71/1500
# 32/32 [==============================] - 1s - loss: 0.6000 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.6109 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 72/1500
# 32/32 [==============================] - 1s - loss: 0.6201 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6088 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 73/1500
# 32/32 [==============================] - 1s - loss: 0.5872 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5839 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 74/1500
# 32/32 [==============================] - 1s - loss: 0.6197 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6293 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 75/1500
# 32/32 [==============================] - 1s - loss: 0.5616 - acc: 0.9062 - recall: 0.9062 - precision: 0.9062 - fmeasure: 0.9062 - val_loss: 0.5934 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 76/1500
# 32/32 [==============================] - 1s - loss: 0.6164 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5798 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 77/1500
# 32/32 [==============================] - 1s - loss: 0.6270 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5537 - val_acc: 0.9062 - val_recall: 0.9062 - val_precision: 0.9062 - val_fmeasure: 0.9062
# Epoch 78/1500
# 32/32 [==============================] - 1s - loss: 0.6525 - acc: 0.6562 - recall: 0.6562 - precision: 0.6562 - fmeasure: 0.6562 - val_loss: 0.5888 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 79/1500
# 32/32 [==============================] - 1s - loss: 0.6261 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6266 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 80/1500
# 32/32 [==============================] - 1s - loss: 0.5881 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.6263 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 81/1500
# 32/32 [==============================] - 1s - loss: 0.5993 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6768 - val_acc: 0.5938 - val_recall: 0.5938 - val_precision: 0.5938 - val_fmeasure: 0.5937
# Epoch 82/1500
# 32/32 [==============================] - 1s - loss: 0.6498 - acc: 0.6562 - recall: 0.6562 - precision: 0.6562 - fmeasure: 0.6562 - val_loss: 0.6653 - val_acc: 0.6250 - val_recall: 0.6250 - val_precision: 0.6250 - val_fmeasure: 0.6250
# Epoch 83/1500
# 32/32 [==============================] - 1s - loss: 0.5981 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5947 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 84/1500
# 32/32 [==============================] - 1s - loss: 0.6090 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6640 - val_acc: 0.6250 - val_recall: 0.6250 - val_precision: 0.6250 - val_fmeasure: 0.6250
# Epoch 85/1500
# 32/32 [==============================] - 1s - loss: 0.5824 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5823 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 86/1500
# 32/32 [==============================] - 1s - loss: 0.5946 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5246 - val_acc: 0.9375 - val_recall: 0.9375 - val_precision: 0.9375 - val_fmeasure: 0.9375
# Epoch 87/1500
# 32/32 [==============================] - 1s - loss: 0.6514 - acc: 0.6562 - recall: 0.6562 - precision: 0.6562 - fmeasure: 0.6562 - val_loss: 0.5917 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 88/1500
# 32/32 [==============================] - 1s - loss: 0.5925 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6057 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 89/1500
# 32/32 [==============================] - 1s - loss: 0.5912 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5608 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 90/1500
# 32/32 [==============================] - 1s - loss: 0.6329 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5891 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 91/1500
# 32/32 [==============================] - 1s - loss: 0.6338 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5900 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 92/1500
# 32/32 [==============================] - 1s - loss: 0.5440 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.5875 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 93/1500
# 32/32 [==============================] - 1s - loss: 0.6174 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6607 - val_acc: 0.6250 - val_recall: 0.6250 - val_precision: 0.6250 - val_fmeasure: 0.6250
# Epoch 94/1500
# 32/32 [==============================] - 1s - loss: 0.5860 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5849 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 95/1500
# 32/32 [==============================] - 1s - loss: 0.6004 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6011 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 96/1500
# 32/32 [==============================] - 1s - loss: 0.5675 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5666 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 97/1500
# 32/32 [==============================] - 1s - loss: 0.6008 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5663 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 98/1500
# 32/32 [==============================] - 1s - loss: 0.5832 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6296 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 99/1500
# 32/32 [==============================] - 1s - loss: 0.5652 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5636 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 100/1500
# 32/32 [==============================] - 1s - loss: 0.6127 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5631 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 101/1500
# 32/32 [==============================] - 1s - loss: 0.5791 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5459 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 102/1500
# 32/32 [==============================] - 1s - loss: 0.6625 - acc: 0.6250 - recall: 0.6250 - precision: 0.6250 - fmeasure: 0.6250 - val_loss: 0.5767 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 103/1500
# 32/32 [==============================] - 1s - loss: 0.5445 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5600 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 104/1500
# 32/32 [==============================] - 1s - loss: 0.5275 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.6280 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 105/1500
# 32/32 [==============================] - 1s - loss: 0.5584 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5244 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 106/1500
# 32/32 [==============================] - 1s - loss: 0.5940 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5923 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 107/1500
# 32/32 [==============================] - 1s - loss: 0.5225 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.5389 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 108/1500
# 32/32 [==============================] - 1s - loss: 0.6446 - acc: 0.6562 - recall: 0.6562 - precision: 0.6562 - fmeasure: 0.6562 - val_loss: 0.6266 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 109/1500
# 32/32 [==============================] - 1s - loss: 0.5551 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5180 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 110/1500
# 32/32 [==============================] - 1s - loss: 0.5731 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5356 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 111/1500
# 32/32 [==============================] - 1s - loss: 0.5719 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5713 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 112/1500
# 32/32 [==============================] - 1s - loss: 0.6080 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5886 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 113/1500
# 32/32 [==============================] - 1s - loss: 0.5887 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5882 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 114/1500
# 32/32 [==============================] - 1s - loss: 0.6065 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5684 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 115/1500
# 32/32 [==============================] - 1s - loss: 0.5122 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.6442 - val_acc: 0.6562 - val_recall: 0.6562 - val_precision: 0.6562 - val_fmeasure: 0.6562
# Epoch 116/1500
# 32/32 [==============================] - 1s - loss: 0.5870 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5286 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 117/1500
# 32/32 [==============================] - 1s - loss: 0.5479 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5666 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 118/1500
# 32/32 [==============================] - 1s - loss: 0.5669 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5466 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 119/1500
# 32/32 [==============================] - 1s - loss: 0.5275 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5255 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 120/1500
# 32/32 [==============================] - 1s - loss: 0.6239 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5052 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 121/1500
# 32/32 [==============================] - 1s - loss: 0.5644 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5841 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 122/1500
# 32/32 [==============================] - 1s - loss: 0.5841 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5237 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 123/1500
# 32/32 [==============================] - 1s - loss: 0.5632 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6029 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 124/1500
# 32/32 [==============================] - 1s - loss: 0.6035 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5418 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 125/1500
# 32/32 [==============================] - 1s - loss: 0.6234 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6231 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 126/1500
# 32/32 [==============================] - 1s - loss: 0.5822 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5407 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 127/1500
# 32/32 [==============================] - 1s - loss: 0.5818 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6022 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 128/1500
# 32/32 [==============================] - 1s - loss: 0.6854 - acc: 0.5938 - recall: 0.5938 - precision: 0.5938 - fmeasure: 0.5937 - val_loss: 0.4980 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 129/1500
# 32/32 [==============================] - 1s - loss: 0.5808 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5390 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 130/1500
# 32/32 [==============================] - 1s - loss: 0.5807 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5384 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 131/1500
# 32/32 [==============================] - 1s - loss: 0.6224 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.4958 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 132/1500
# 32/32 [==============================] - 1s - loss: 0.5593 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5373 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 133/1500
# 32/32 [==============================] - 1s - loss: 0.5586 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6225 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 134/1500
# 32/32 [==============================] - 1s - loss: 0.5583 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5795 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 135/1500
# 32/32 [==============================] - 1s - loss: 0.5149 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5358 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 136/1500
# 32/32 [==============================] - 1s - loss: 0.6871 - acc: 0.5938 - recall: 0.5938 - precision: 0.5938 - fmeasure: 0.5937 - val_loss: 0.6004 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 137/1500
# 32/32 [==============================] - 1s - loss: 0.6438 - acc: 0.6562 - recall: 0.6562 - precision: 0.6562 - fmeasure: 0.6562 - val_loss: 0.6874 - val_acc: 0.5938 - val_recall: 0.5938 - val_precision: 0.5938 - val_fmeasure: 0.5937
# Epoch 138/1500
# 32/32 [==============================] - 1s - loss: 0.5787 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5786 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 139/1500
# 32/32 [==============================] - 1s - loss: 0.6441 - acc: 0.6562 - recall: 0.6562 - precision: 0.6562 - fmeasure: 0.6562 - val_loss: 0.5564 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 140/1500
# 32/32 [==============================] - 1s - loss: 0.5563 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5999 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 141/1500
# 32/32 [==============================] - 1s - loss: 0.5339 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5557 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 142/1500
# 32/32 [==============================] - 1s - loss: 0.6222 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5110 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 143/1500
# 32/32 [==============================] - 1s - loss: 0.5776 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5106 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 144/1500
# 32/32 [==============================] - 1s - loss: 0.6219 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5325 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 145/1500
# 32/32 [==============================] - 1s - loss: 0.4430 - acc: 0.9375 - recall: 0.9375 - precision: 0.9375 - fmeasure: 0.9375 - val_loss: 0.5990 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 146/1500
# 32/32 [==============================] - 1s - loss: 0.6217 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5993 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 147/1500
# 32/32 [==============================] - 1s - loss: 0.5317 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5538 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 148/1500
# 32/32 [==============================] - 1s - loss: 0.6216 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5078 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 149/1500
# 32/32 [==============================] - 1s - loss: 0.5307 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5986 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 150/1500
# 32/32 [==============================] - 1s - loss: 0.4845 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.5297 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 151/1500
# 32/32 [==============================] - 1s - loss: 0.6215 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6213 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 152/1500
# 32/32 [==============================] - 1s - loss: 0.5525 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5521 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 153/1500
# 32/32 [==============================] - 1s - loss: 0.5754 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.4821 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 154/1500
# 32/32 [==============================] - 1s - loss: 0.5980 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6212 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 155/1500
# 32/32 [==============================] - 1s - loss: 0.6215 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5512 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 156/1500
# 32/32 [==============================] - 1s - loss: 0.4336 - acc: 0.9375 - recall: 0.9375 - precision: 0.9375 - fmeasure: 0.9375 - val_loss: 0.5271 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 157/1500
# 32/32 [==============================] - 1s - loss: 0.6448 - acc: 0.6562 - recall: 0.6562 - precision: 0.6562 - fmeasure: 0.6562 - val_loss: 0.5030 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 158/1500
# 32/32 [==============================] - 1s - loss: 0.5029 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5500 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 159/1500
# 32/32 [==============================] - 1s - loss: 0.5974 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5020 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 160/1500
# 32/32 [==============================] - 1s - loss: 0.6212 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5494 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 161/1500
# 32/32 [==============================] - 1s - loss: 0.4298 - acc: 0.9375 - recall: 0.9375 - precision: 0.9375 - fmeasure: 0.9375 - val_loss: 0.5011 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 162/1500
# 32/32 [==============================] - 1s - loss: 0.5971 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.4763 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 163/1500
# 32/32 [==============================] - 1s - loss: 0.6211 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5968 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 164/1500
# 32/32 [==============================] - 1s - loss: 0.5728 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5970 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 165/1500
# 32/32 [==============================] - 1s - loss: 0.5724 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5234 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 166/1500
# 32/32 [==============================] - 1s - loss: 0.5968 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5232 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 167/1500
# 32/32 [==============================] - 1s - loss: 0.5722 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.4982 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 168/1500
# 32/32 [==============================] - 1s - loss: 0.4489 - acc: 0.9062 - recall: 0.9062 - precision: 0.9062 - fmeasure: 0.9062 - val_loss: 0.5472 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 169/1500
# 32/32 [==============================] - 1s - loss: 0.5225 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5717 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 170/1500
# 32/32 [==============================] - 1s - loss: 0.4972 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5714 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 171/1500
# 32/32 [==============================] - 1s - loss: 0.5216 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5210 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 172/1500
# 32/32 [==============================] - 1s - loss: 0.5462 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5709 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 173/1500
# 32/32 [==============================] - 1s - loss: 0.5206 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.4950 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 174/1500
# 32/32 [==============================] - 1s - loss: 0.5202 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5451 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 175/1500
# 32/32 [==============================] - 1s - loss: 0.5959 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.4940 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 176/1500
# 32/32 [==============================] - 1s - loss: 0.6978 - acc: 0.5938 - recall: 0.5938 - precision: 0.5938 - fmeasure: 0.5937 - val_loss: 0.4679 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 177/1500
# 32/32 [==============================] - 1s - loss: 0.4422 - acc: 0.9062 - recall: 0.9062 - precision: 0.9062 - fmeasure: 0.9062 - val_loss: 0.6214 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 178/1500
# 32/32 [==============================] - 1s - loss: 0.6214 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5956 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 179/1500
# 32/32 [==============================] - 1s - loss: 0.4408 - acc: 0.9062 - recall: 0.9062 - precision: 0.9062 - fmeasure: 0.9062 - val_loss: 0.5180 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 180/1500
# 32/32 [==============================] - 1s - loss: 0.5439 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5694 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 181/1500
# 32/32 [==============================] - 1s - loss: 0.5436 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5432 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 182/1500
# 32/32 [==============================] - 1s - loss: 0.5952 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.4905 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 183/1500
# 32/32 [==============================] - 1s - loss: 0.5690 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5163 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 184/1500
# 32/32 [==============================] - 1s - loss: 0.5690 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.4105 - val_acc: 0.9375 - val_recall: 0.9375 - val_precision: 0.9375 - val_fmeasure: 0.9375
# Epoch 185/1500
# 32/32 [==============================] - 1s - loss: 0.6216 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5157 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 186/1500
# 32/32 [==============================] - 1s - loss: 0.5422 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5951 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 187/1500
# 32/32 [==============================] - 1s - loss: 0.4094 - acc: 0.9375 - recall: 0.9375 - precision: 0.9375 - fmeasure: 0.9375 - val_loss: 0.4087 - val_acc: 0.9375 - val_recall: 0.9375 - val_precision: 0.9375 - val_fmeasure: 0.9375
# Epoch 188/1500
# 32/32 [==============================] - 1s - loss: 0.5151 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.4878 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 189/1500
# 32/32 [==============================] - 1s - loss: 0.5950 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.4876 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 190/1500
# 32/32 [==============================] - 1s - loss: 0.5413 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5141 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 191/1500
# 32/32 [==============================] - 1s - loss: 0.5411 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5676 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 192/1500
# 32/32 [==============================] - 1s - loss: 0.5137 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5948 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 193/1500
# ...
# Epoch 1437/1500
# 32/32 [==============================] - 1s - loss: 0.4855 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.4458 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 1438/1500
# 32/32 [==============================] - 1s - loss: 0.6049 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.4061 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 1439/1500
# 32/32 [==============================] - 1s - loss: 0.6048 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.3664 - val_acc: 0.9062 - val_recall: 0.9062 - val_precision: 0.9062 - val_fmeasure: 0.9062
# Epoch 1440/1500
# 32/32 [==============================] - 1s - loss: 0.4459 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.4856 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 1441/1500
# 32/32 [==============================] - 1s - loss: 0.6843 - acc: 0.6562 - recall: 0.6562 - precision: 0.6562 - fmeasure: 0.6562 - val_loss: 0.5253 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1442/1500
# 32/32 [==============================] - 1s - loss: 0.6444 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.4063 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 1443/1500
# 32/32 [==============================] - 1s - loss: 0.5650 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.4064 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 1444/1500
# 32/32 [==============================] - 1s - loss: 0.6443 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.4857 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 1445/1500
# 32/32 [==============================] - 1s - loss: 0.5650 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6442 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 1446/1500
# 32/32 [==============================] - 1s - loss: 0.5649 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.4858 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 1447/1500
# 32/32 [==============================] - 1s - loss: 0.4462 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5253 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1448/1500
# 32/32 [==============================] - 1s - loss: 0.4463 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5253 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1449/1500
# 32/32 [==============================] - 1s - loss: 0.6044 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5649 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 1450/1500
# 32/32 [==============================] - 1s - loss: 0.4463 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5253 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1451/1500
# 32/32 [==============================] - 1s - loss: 0.4068 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.2883 - val_acc: 0.9688 - val_recall: 0.9688 - val_precision: 0.9688 - val_fmeasure: 0.9687
# Epoch 1452/1500
# 32/32 [==============================] - 1s - loss: 0.6439 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.4858 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 1453/1500
# 32/32 [==============================] - 1s - loss: 0.5648 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5254 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1454/1500
# 32/32 [==============================] - 1s - loss: 0.6438 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6043 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 1455/1500
# 32/32 [==============================] - 1s - loss: 0.4069 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.4859 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 1456/1500
# 32/32 [==============================] - 1s - loss: 0.6437 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.5253 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1457/1500
# 32/32 [==============================] - 1s - loss: 0.5253 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5253 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1458/1500
# 32/32 [==============================] - 1s - loss: 0.6042 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5254 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1459/1500
# 32/32 [==============================] - 1s - loss: 0.3676 - acc: 0.9062 - recall: 0.9062 - precision: 0.9062 - fmeasure: 0.9062 - val_loss: 0.5254 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1460/1500
# 32/32 [==============================] - 1s - loss: 0.6042 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5648 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 1461/1500
# 32/32 [==============================] - 1s - loss: 0.5647 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.3677 - val_acc: 0.9062 - val_recall: 0.9062 - val_precision: 0.9062 - val_fmeasure: 0.9062
# Epoch 1462/1500
# 32/32 [==============================] - 1s - loss: 0.4859 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5648 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 1463/1500
# 32/32 [==============================] - 1s - loss: 0.7617 - acc: 0.5938 - recall: 0.5938 - precision: 0.5938 - fmeasure: 0.5937 - val_loss: 0.3678 - val_acc: 0.9062 - val_recall: 0.9062 - val_precision: 0.9062 - val_fmeasure: 0.9062
# Epoch 1464/1500
# 32/32 [==============================] - 1s - loss: 0.4860 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.4466 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 1465/1500
# 32/32 [==============================] - 1s - loss: 0.4466 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.5254 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1466/1500
# 32/32 [==============================] - 1s - loss: 0.6434 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.3680 - val_acc: 0.9062 - val_recall: 0.9062 - val_precision: 0.9062 - val_fmeasure: 0.9062
# Epoch 1467/1500
# 32/32 [==============================] - 1s - loss: 0.5647 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.4074 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 1468/1500
# 32/32 [==============================] - 1s - loss: 0.6040 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6826 - val_acc: 0.6562 - val_recall: 0.6562 - val_precision: 0.6562 - val_fmeasure: 0.6562
# Epoch 1469/1500
# 32/32 [==============================] - 1s - loss: 0.6040 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.5646 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 1470/1500
# 32/32 [==============================] - 1s - loss: 0.6039 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.6432 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 1471/1500
# 32/32 [==============================] - 1s - loss: 0.5254 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6039 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 1472/1500
# 32/32 [==============================] - 1s - loss: 0.3684 - acc: 0.9062 - recall: 0.9062 - precision: 0.9062 - fmeasure: 0.9062 - val_loss: 0.4861 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 1473/1500
# 32/32 [==============================] - 1s - loss: 0.5254 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.4861 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 1474/1500
# 32/32 [==============================] - 1s - loss: 0.4861 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.4469 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 1475/1500
# 32/32 [==============================] - 1s - loss: 0.5646 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5646 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 1476/1500
# 32/32 [==============================] - 1s - loss: 0.6430 - acc: 0.6875 - recall: 0.6875 - precision: 0.6875 - fmeasure: 0.6875 - val_loss: 0.6822 - val_acc: 0.6562 - val_recall: 0.6562 - val_precision: 0.6562 - val_fmeasure: 0.6562
# Epoch 1477/1500
# 32/32 [==============================] - 1s - loss: 0.5646 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5254 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1478/1500
# 32/32 [==============================] - 1s - loss: 0.7997 - acc: 0.5625 - recall: 0.5625 - precision: 0.5625 - fmeasure: 0.5625 - val_loss: 0.5254 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1479/1500
# 32/32 [==============================] - 1s - loss: 0.5645 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.5254 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1480/1500
# 32/32 [==============================] - 1s - loss: 0.5254 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.6036 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 1481/1500
# 32/32 [==============================] - 1s - loss: 0.4471 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.6036 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 1482/1500
# 32/32 [==============================] - 1s - loss: 0.4863 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5254 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1483/1500
# 32/32 [==============================] - 1s - loss: 0.5254 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.3691 - val_acc: 0.9062 - val_recall: 0.9062 - val_precision: 0.9062 - val_fmeasure: 0.9062
# Epoch 1484/1500
# 32/32 [==============================] - 1s - loss: 0.5645 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.4863 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 1485/1500
# 32/32 [==============================] - 1s - loss: 0.5644 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6035 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 1486/1500
# 32/32 [==============================] - 1s - loss: 0.5644 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.4083 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 1487/1500
# 32/32 [==============================] - 1s - loss: 0.5254 - acc: 0.7812 - recall: 0.7812 - precision: 0.7812 - fmeasure: 0.7812 - val_loss: 0.5644 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 1488/1500
# 32/32 [==============================] - 1s - loss: 0.4863 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.4083 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 1489/1500
# 32/32 [==============================] - 1s - loss: 0.4864 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5644 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 1490/1500
# 32/32 [==============================] - 1s - loss: 0.6034 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.4084 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 1491/1500
# 32/32 [==============================] - 1s - loss: 0.3694 - acc: 0.9062 - recall: 0.9062 - precision: 0.9062 - fmeasure: 0.9062 - val_loss: 0.4864 - val_acc: 0.8125 - val_recall: 0.8125 - val_precision: 0.8125 - val_fmeasure: 0.8125
# Epoch 1492/1500
# 32/32 [==============================] - 1s - loss: 0.4864 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5644 - val_acc: 0.7500 - val_recall: 0.7500 - val_precision: 0.7500 - val_fmeasure: 0.7500
# Epoch 1493/1500
# 32/32 [==============================] - 1s - loss: 0.6034 - acc: 0.7188 - recall: 0.7188 - precision: 0.7188 - fmeasure: 0.7187 - val_loss: 0.4083 - val_acc: 0.8750 - val_recall: 0.8750 - val_precision: 0.8750 - val_fmeasure: 0.8750
# Epoch 1494/1500
# 32/32 [==============================] - 1s - loss: 0.4083 - acc: 0.8750 - recall: 0.8750 - precision: 0.8750 - fmeasure: 0.8750 - val_loss: 0.4473 - val_acc: 0.8438 - val_recall: 0.8438 - val_precision: 0.8438 - val_fmeasure: 0.8437
# Epoch 1495/1500
# 32/32 [==============================] - 1s - loss: 0.4864 - acc: 0.8125 - recall: 0.8125 - precision: 0.8125 - fmeasure: 0.8125 - val_loss: 0.5254 - val_acc: 0.7812 - val_recall: 0.7812 - val_precision: 0.7812 - val_fmeasure: 0.7812
# Epoch 1496/1500
# 32/32 [==============================] - 1s - loss: 0.4473 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.6425 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 1497/1500
# 32/32 [==============================] - 1s - loss: 0.4473 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.3691 - val_acc: 0.9062 - val_recall: 0.9062 - val_precision: 0.9062 - val_fmeasure: 0.9062
# Epoch 1498/1500
# 32/32 [==============================] - 1s - loss: 0.7207 - acc: 0.6250 - recall: 0.6250 - precision: 0.6250 - fmeasure: 0.6250 - val_loss: 0.6426 - val_acc: 0.6875 - val_recall: 0.6875 - val_precision: 0.6875 - val_fmeasure: 0.6875
# Epoch 1499/1500
# 32/32 [==============================] - 1s - loss: 0.4473 - acc: 0.8438 - recall: 0.8438 - precision: 0.8438 - fmeasure: 0.8437 - val_loss: 0.6035 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187
# Epoch 1500/1500
# 32/32 [==============================] - 1s - loss: 0.5644 - acc: 0.7500 - recall: 0.7500 - precision: 0.7500 - fmeasure: 0.7500 - val_loss: 0.6035 - val_acc: 0.7188 - val_recall: 0.7188 - val_precision: 0.7188 - val_fmeasure: 0.7187

# %% [markdown]
# ## 7. Evaluating the results

# %%
history.history.keys()
# Out:
# ['acc',
#  'loss',
#  'val_fmeasure',
#  'recall',
#  'precision',
#  'fmeasure',
#  'val_acc',
#  'val_recall',
#  'val_precision',
#  'val_loss']

# %%
train_history = history.history['acc']
valid_history = history.history['val_acc']

# %%
 # Plotting training accuracy and testing accuracy acros epochs
plt.figure(figsize=(20,10))
plt.plot(train_history)
plt.plot(valid_history)
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig(PIC_NAME)

# %%
# Tail-rolling average transform
series_train = Series(train_history)
rolling_train = series_train.rolling(window=100)
rolling_mean_train = rolling_train.mean()

series_valid = Series(valid_history)
rolling_valid = series_valid.rolling(window=100)
rolling_mean_valid = rolling_valid.mean()

# %%
plt.figure(figsize=(20,10))
plt.plot(rolling_mean_train)
plt.plot(rolling_mean_valid)
plt.title('Smoothened training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Saving histories
np.save(TRA_HISTORY_NAME, train_history)
np.save(VAL_HISTORY_NAME, valid_history)

# %%
# saving weights
model.save_weights(WEIGHTS_NAME)

# %% [markdown]
# ### Results on Adience

# %%
model.evaluate_generator(adience_gender_test_gen,BATCH_SIZE*400)
# Out:
# [0.92066032348014715,
#  0.46512352902996468,
#  0.46512352902996468,
#  0.46512352902996468,
#  0.46512346940209309]

# %%
raise EX

# %% [markdown]
# ## Finetuning with Adience

# %%
history = model.fit_generator(adience_gender_train_gen, 
                              validation_data=adience_gender_valid_gen,
                              nb_val_samples=BATCH_SIZE,
                              samples_per_epoch=BATCH_SIZE, 
                              nb_epoch=NUM_EPOCHS2)

# %%
train_history = history.history['acc']
valid_history = history.history['val_acc']

# %%
 # Plotting training accuracy and testing accuracy acros epochs
plt.figure(figsize=(20,10))
plt.plot(train_history)
plt.plot(valid_history)
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig(PIC_NAME_FINETUNING)

# %%
# Tail-rolling average transform
series_train = Series(train_history)
rolling_train = series_train.rolling(window=100)
rolling_mean_train = rolling_train.mean()

series_valid = Series(valid_history)
rolling_valid = series_valid.rolling(window=100)
rolling_mean_valid = rolling_valid.mean()

# %%
plt.figure(figsize=(20,10))
plt.plot(rolling_mean_train)
plt.plot(rolling_mean_valid)
plt.title('Smoothened training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Saving histories
np.save(TRA_HISTORY_NAME_FINETUNING, train_history)
np.save(VAL_HISTORY_NAME_FINETUNING, valid_history)

# %%
# saving weights
model.save_weights(WEIGHTS_NAME_FINETUNING)

# %%
model.evaluate_generator(adience_gender_test_gen,BATCH_SIZE*400)
