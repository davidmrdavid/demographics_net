# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## 1. Setup

# %%
# NECESSARY IMPORTS
import pandas as pd
import numpy  as np

from keras.models     import Sequential
from keras.layers     import Dense, Dropout, Activation, Flatten, advanced_activations
from keras.layers     import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD, Adam

from keras.utils.data_utils import get_file
from keras import initializations
from keras.callbacks import ModelCheckpoint
import keras.backend     as K
import matplotlib.pyplot as plt

from pandas                     import Series
from scipy.misc                 import imresize
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image  import (ImageDataGenerator, 
                                        array_to_img,
                                        img_to_array,
                                        load_img)
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
# Out:
# Using TensorFlow backend.

# %%
# VGG16-Face Pre-trained weights download links
TF_WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5'
VGG16_LOCAL_W   = "'vgg16_weights_tf_dim_ordering_tf_kernels.h5'"

# %%
# %matplotlib inline

# %%
# Ensure reproducibility
np.random.seed(0)

# %%
# Path constants
DATA_TEMPLATE     = "./../../data/"
ADIENCE_META_P    = DATA_TEMPLATE + "adience/meta"
ADIENCE_RAW_P     = DATA_TEMPLATE + "adience/keras_format"
ADIENCE_AGE_P     = ADIENCE_RAW_P + "/age"
ADIENCE_GEN_P     = ADIENCE_RAW_P + "/gender"
IMG_PATH          = DATA_TEMPLATE + "wiki/%s"

WIKI_META_P       = DATA_TEMPLATE + "wiki_meta"
MODEL_TEMPLATE    = "./models/%s"
WEIGHTS_TEMPLATE  = "./weights/%s"
GRAPHS_TEMPLATE   = "./graphs/%s"
HISTORY_TEMPLATE   = "./histories/%s"

# %%
# Independent constants
MODEL_NAME = "1_gender_SGD1e3_randomNormal_LHet_ReLu-OG"
INITIALIZATION = 'normal'
LOSS           = "categorical_crossentropy"
OPTIMIZER      = SGD(lr=1e-3, momentum=0.9, decay=5e-4)
BATCH_SIZE     = 32


PIC_NAME     = GRAPHS_TEMPLATE % (MODEL_NAME + ".png")
PIC_NAME_FINETUNING = GRAPHS_TEMPLATE % (MODEL_NAME + "_finetuning_.png")
WEIGHTS_NAME = WEIGHTS_TEMPLATE % (MODEL_NAME + ".h5")
TRA_HISTORY_NAME = HISTORY_TEMPLATE % (MODEL_NAME + "_train_"+".npy")
VAL_HISTORY_NAME = HISTORY_TEMPLATE % (MODEL_NAME + "_valid_"+".npy")


WEIGHTS_NAME_FINETUNING = WEIGHTS_TEMPLATE % (MODEL_NAME + "_finetuning_.h5")
TRA_HISTORY_NAME_FINETUNING = HISTORY_TEMPLATE % (MODEL_NAME + "_train_"+"_finetuning_.npy")
VAL_HISTORY_NAME_FINETUNING = HISTORY_TEMPLATE % (MODEL_NAME + "_valid_"+"_finetuning_.npy")

IMG_WIDTH  = 227
IMG_HEIGHT = 227


ADIENCE_FULL = ["idx","user_id","face_id","original_image","gender","age","img_path","keras_path"]
ADIENCE_HEADER = ["user_id","face_id","original_image","gender","age","img_path","keras_path"]
WIKI_HEADER    = ["full_path","age","gender"]

NUM_EPOCHS  = 1500
NUM_EPOCHS2 = 500


BEST_CHECKPOINT = MODEL_NAME + ".weights.{epoch:02d}-{val_loss:.2f}.hdf5"
BEST_CHECKPOINT_FINE = MODEL_NAME + "FINETUNE.weights.{epoch:02d}-{val_loss:.2f}.hdf5"

# %%
callback1 = ModelCheckpoint(BEST_CHECKPOINT, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=10)

# %%
callback2 = ModelCheckpoint(BEST_CHECKPOINT_FINE, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=10)

# %%
# Dependent constants
IMG_DIMS = (IMG_WIDTH, IMG_HEIGHT)
MODEL_W  = MODEL_NAME + ".h5"
MODEL_P  = MODEL_NAME + ".txt"

# %% [markdown]
# ## 2. Loading metadata

# %% [markdown]
# ### Adience

# %%
gender_train_path = ADIENCE_META_P + "/gender_train_0.csv"
gender_valid_path = ADIENCE_META_P + "/gender_valid_0.csv"
gender_train = pd.read_csv(filepath_or_buffer =gender_train_path)
gender_valid = pd.read_csv(filepath_or_buffer =gender_valid_path)

gender_train = gender_train[ADIENCE_HEADER]
gender_valid = gender_valid[ADIENCE_HEADER]

# %%
age_train_path = ADIENCE_META_P + "/age_train_0.csv"
age_valid_path = ADIENCE_META_P + "/age_valid_0.csv"
age_train = pd.read_csv(filepath_or_buffer =gender_train_path)
age_valid = pd.read_csv(filepath_or_buffer =gender_valid_path)

age_train = age_train[ADIENCE_HEADER]
age_valid = age_valid[ADIENCE_HEADER]

# %% [markdown]
# ### Wiki

# %%
w_gender_train_path = WIKI_META_P + "/gender/train_1.csv"
w_gender_valid_path = WIKI_META_P + "/gender/valid_1.csv"

w_gender_train = pd.read_csv(filepath_or_buffer =w_gender_train_path)
w_gender_valid = pd.read_csv(filepath_or_buffer =w_gender_valid_path)

w_gender_train = w_gender_train[WIKI_HEADER]
w_gender_valid = w_gender_valid[WIKI_HEADER]

# %%
w_age_train_path = WIKI_META_P + "/gender/train_1.csv"
w_age_valid_path = WIKI_META_P + "/gender/valid_1.csv"
w_age_train = pd.read_csv(filepath_or_buffer =w_age_train_path)
w_age_valid = pd.read_csv(filepath_or_buffer =w_age_valid_path)

w_age_train = w_age_train[WIKI_HEADER]
w_age_valid = w_age_valid[WIKI_HEADER]

# %% [markdown]
# ### SHALLOW-ONLY TASK: Fix age ranges

# %%
"""
def fix_age_ranges(age):
    if age < 4:
        return "(0, 2)"
    if age < 8:
        return "(4, 6)"
    if age < 15:
        return "(8, 13)"
    if age < 25:
        return "(15, 20)"
    if age < 38:
        return "(25, 32)"
    if age < 48:
        return "(38, 43)"
    if age < 60:
        return "(48, 53)"
    return "(60-100)"

w_age_train["age"]    = w_age_train["age"].apply(lambda x: fix_age_ranges(x))
w_age_valid["age"]    = w_age_valid["age"].apply(lambda x: fix_age_ranges(x))
w_gender_train["age"] = w_gender_train["age"].apply(lambda x: fix_age_ranges(x))
w_gender_valid["age"] = w_gender_valid["age"].apply(lambda x: fix_age_ranges(x))
"""
# Out:
# '\ndef fix_age_ranges(age):\n    if age < 4:\n        return "(0, 2)"\n    if age < 8:\n        return "(4, 6)"\n    if age < 15:\n        return "(8, 13)"\n    if age < 25:\n        return "(15, 20)"\n    if age < 38:\n        return "(25, 32)"\n    if age < 48:\n        return "(38, 43)"\n    if age < 60:\n        return "(48, 53)"\n    return "(60-100)"\n\nw_age_train["age"]    = w_age_train["age"].apply(lambda x: fix_age_ranges(x))\nw_age_valid["age"]    = w_age_valid["age"].apply(lambda x: fix_age_ranges(x))\nw_gender_train["age"] = w_gender_train["age"].apply(lambda x: fix_age_ranges(x))\nw_gender_valid["age"] = w_gender_valid["age"].apply(lambda x: fix_age_ranges(x))\n'

# %% [markdown]
# ## 3. Data pipeline

# %% [markdown]
# ### 3.1 Adience

# %%
adience_train_aug = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        rescale=1./255,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
adience_valid_aug = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ### Train

# %%
ADIENCE_GENDER_TRAIN_P = ADIENCE_GEN_P + "/train/1"
adience_gender_train_gen = adience_train_aug.flow_from_directory(
    ADIENCE_GENDER_TRAIN_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 10505 images belonging to 2 classes.

# %%
ADIENCE_AGE_TRAIN_P = ADIENCE_AGE_P + "/train/1"
adience_age_train_gen = adience_train_aug.flow_from_directory(
    ADIENCE_AGE_TRAIN_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 10505 images belonging to 8 classes.

# %% [markdown]
# ### Validation

# %%
ADIENCE_GENDER_VALID_P = ADIENCE_GEN_P + "/valid/1"
adience_gender_valid_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_GENDER_VALID_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3502 images belonging to 2 classes.

# %%
ADIENCE_AGE_VALID_P = ADIENCE_AGE_P + "/valid/1"
adience_age_valid_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_AGE_VALID_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3502 images belonging to 8 classes.

# %% [markdown]
# ### Test

# %%
ADIENCE_GENDER_TEST_P = ADIENCE_GEN_P + "/test/"
adience_gender_test_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_GENDER_TEST_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3445 images belonging to 2 classes.

# %%
ADIENCE_AGE_TEST_P = ADIENCE_AGE_P + "/test/"
adience_age_test_gen = adience_valid_aug.flow_from_directory(
    ADIENCE_AGE_TEST_P,
    target_size=IMG_DIMS,
    batch_size=BATCH_SIZE,
    class_mode="categorical")
# Out:
# Found 3445 images belonging to 8 classes.

# %% [markdown]
# ### 3.2 Wiki

# %%
true_path = lambda x: IMG_PATH % x
w_age_train["full_path"]    = w_age_train["full_path"].apply(lambda x: true_path(x))
w_gender_train["full_path"] = w_gender_train["full_path"].apply(lambda x: true_path(x))
w_age_valid["full_path"]    = w_age_valid["full_path"].apply(lambda x: true_path(x))
w_gender_valid["full_path"] = w_gender_valid["full_path"].apply(lambda x: true_path(x))

# %%
def get_image(x):
    try:
        val = img_to_array(imresize(load_img(x),IMG_DIMS))
    except:
        val = "ERR"
    return val

# %%
# Data generator
def generate_test(df, batch_size, target_feature):
    start, end = 0, batch_size
    while True:
        while end < len(dfs.shape[0]):
            #ages_h = list(pd.get_dummies(data["age"]).columns.values)
            #ages   = pd.get_dummies(data["age"])
            #data[ages_h] = ages

            sample = data[start:end]
            start += batch_size
            end   += batch_size

            X         = pd.DataFrame(sample["full_path"].apply(lambda x:get_image(x)))
            good_rows = X["full_path"] != "ERR"
            X         = X[good_rows]
            X.reset_index(inplace=True)
            X = X["full_path"].apply(lambda x: x.reshape((1,)+ x.shape))
            X = np.vstack(X)
            X /= 255

            #X = model.predict(X, X.shape[0])

            Y = sample[good_rows]
            if target_feature == "age":
                Y = Y["age"]
            else:
                Y = pd.get_dummies(Y["gender"]).as_matrix()
            yield (X,Y)

# %%
# Data generator
def generate_data(df, batch_size, target_feature):
    start, end = 0, batch_size
    while True:
        data   = df.sample(frac=1).reset_index(drop=True)
        #ages_h = list(pd.get_dummies(data["age"]).columns.values)
        #ages   = pd.get_dummies(data["age"])
        #data[ages_h] = ages
        
        sample = data[start:end]
        
        X         = pd.DataFrame(sample["full_path"].apply(lambda x:get_image(x)))
        good_rows = X["full_path"] != "ERR"
        X         = X[good_rows]
        X.reset_index(inplace=True)
        X = X["full_path"].apply(lambda x: x.reshape((1,)+ x.shape))
        X = np.vstack(X)
        X /= 255
        #X = model.predict(X, X.shape[0])
        
        Y = sample[good_rows]
        if target_feature == "age":
            Y = Y["age"].as_matrix()
        else:
            Y = pd.get_dummies(Y["gender"]).as_matrix()
        yield (X,Y)

# %%
w_age_train_gen = generate_data(w_age_train, BATCH_SIZE, "age")
w_age_valid_gen = generate_data(w_age_valid, BATCH_SIZE, "age")
w_gender_train_gen = generate_data(w_gender_train, BATCH_SIZE, "gender")
w_gender_valid_gen = generate_data(w_gender_valid, BATCH_SIZE, "gender")

# %%
from keras.engine.topology import Layer
class LRN2D(Layer):
    """
    This code is adapted from pylearn2.
    License at: https://github.com/lisa-lab/pylearn2/blob/master/LICENSE.txt
    """

    def __init__(self, alpha=1e-4, k=2, beta=0.75, n=5):
        if n % 2 == 0:
            raise NotImplementedError("LRN2D only works with odd n. n provided: " + str(n))
        super(LRN2D, self).__init__()
        self.alpha = alpha
        self.k = k
        self.beta = beta
        self.n = n

    def get_output(self, train):
        X = self.get_input(train)
        b, ch, r, c = X.shape
        half_n = self.n // 2
        input_sqr = T.sqr(X)
        extra_channels = T.alloc(0., b, ch + 2*half_n, r, c)
        input_sqr = T.set_subtensor(extra_channels[:, half_n:half_n+ch, :, :], input_sqr)
        scale = self.k
        for i in range(self.n):
            scale += self.alpha * input_sqr[:, i:i+ch, :, :]
        scale = scale ** self.beta
        return X / scale

    def get_config(self):
        return {"name": self.__class__.__name__,
                "alpha": self.alpha,
                "k": self.k,
                "beta": self.beta,
"n": self.n}

# %% [markdown]
# ## 4. Building the model

# %%
# VGG16 network
model = Sequential()
model.add(ZeroPadding2D((1, 1), input_shape=(IMG_WIDTH, IMG_HEIGHT,3)))

model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_2'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_2'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_2'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_2'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_1'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_2'))
model.add(ZeroPadding2D((1, 1)))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(Flatten())
model.add(Dense(4096, activation='relu', name="fc_1"))
model.add(Dense(4096, activation='relu', name="fc_w"))
model.add(Dense(1000, activation='softmax',  name="predictions"))

# %%
# Obtain VGG16-Face weights
weights_path = get_file(VGG16_LOCAL_W,TF_WEIGHTS_PATH, cache_subdir='models')

# %%
# Loading VGG16-Face weights to VGG16 network
model.load_weights(weights_path)

# %%
from keras import backend as K

def my_init(shape, name=None):
    return K.variable(np.reshape(np.arange(0, shape[0], 1), (101,1)), name=name)

# %%
model.layers.pop()
model.add(Dense(101))
model.add(Activation("softmax"))
model.add(Dense(1, init=my_init))

# %%
layer = model.layers[-1]
layer.trainable = False

for layer in model.layers[:25]:
    layer.trainable = False

# %%
# Compile
model.compile(loss='mean_squared_error', optimizer=OPTIMIZER, metrics=['mse','mae'])

# %%
#model.compile(loss=LOSS, optimizer=OPTIMIZER, metrics=['accuracy', 'recall', 'precision','f1score'])

# %% [markdown]
# ## 6. Training the model

# %%
history = model.fit_generator(w_age_train_gen, 
                              validation_data=w_age_valid_gen,
                              nb_val_samples=BATCH_SIZE,
                              samples_per_epoch=BATCH_SIZE, 
                              nb_epoch=NUM_EPOCHS)
# Out:
# Epoch 1/1500
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.py:739: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = lib.scalar_compare(x, y, op)
# 32/32 [==============================] - 6s - loss: 485.1611 - mean_squared_error: 485.1611 - mean_absolute_error: 18.9011 - val_loss: 392.4735 - val_mean_squared_error: 392.4735 - val_mean_absolute_error: 18.0347
# Epoch 2/1500
# 32/32 [==============================] - 1s - loss: 387.5511 - mean_squared_error: 387.5511 - mean_absolute_error: 18.0264 - val_loss: 430.8040 - val_mean_squared_error: 430.8040 - val_mean_absolute_error: 18.4755
# Epoch 3/1500
# 32/32 [==============================] - 1s - loss: 408.4183 - mean_squared_error: 408.4183 - mean_absolute_error: 18.5317 - val_loss: 377.5533 - val_mean_squared_error: 377.5533 - val_mean_absolute_error: 17.1771
# Epoch 4/1500
# 32/32 [==============================] - 1s - loss: 427.4346 - mean_squared_error: 427.4346 - mean_absolute_error: 18.5873 - val_loss: 382.6092 - val_mean_squared_error: 382.6092 - val_mean_absolute_error: 17.7640
# Epoch 5/1500
# 32/32 [==============================] - 1s - loss: 418.9250 - mean_squared_error: 418.9250 - mean_absolute_error: 18.2009 - val_loss: 294.8061 - val_mean_squared_error: 294.8061 - val_mean_absolute_error: 14.7598
# Epoch 6/1500
# 32/32 [==============================] - 1s - loss: 316.2582 - mean_squared_error: 316.2582 - mean_absolute_error: 16.3562 - val_loss: 305.2530 - val_mean_squared_error: 305.2530 - val_mean_absolute_error: 14.3020
# Epoch 7/1500
# 32/32 [==============================] - 1s - loss: 317.1317 - mean_squared_error: 317.1317 - mean_absolute_error: 15.2708 - val_loss: 345.1959 - val_mean_squared_error: 345.1959 - val_mean_absolute_error: 15.6834
# Epoch 8/1500
# 32/32 [==============================] - 1s - loss: 320.1948 - mean_squared_error: 320.1948 - mean_absolute_error: 14.8475 - val_loss: 407.3110 - val_mean_squared_error: 407.3110 - val_mean_absolute_error: 17.9351
# Epoch 9/1500
# 32/32 [==============================] - 1s - loss: 351.7124 - mean_squared_error: 351.7124 - mean_absolute_error: 16.2197 - val_loss: 406.1625 - val_mean_squared_error: 406.1625 - val_mean_absolute_error: 16.5998
# Epoch 10/1500
# 32/32 [==============================] - 1s - loss: 297.8176 - mean_squared_error: 297.8176 - mean_absolute_error: 15.6995 - val_loss: 354.2526 - val_mean_squared_error: 354.2526 - val_mean_absolute_error: 15.9477
# Epoch 11/1500
# 32/32 [==============================] - 1s - loss: 254.2046 - mean_squared_error: 254.2046 - mean_absolute_error: 12.5255 - val_loss: 353.0198 - val_mean_squared_error: 353.0198 - val_mean_absolute_error: 14.7638
# Epoch 12/1500
# 32/32 [==============================] - 1s - loss: 259.5467 - mean_squared_error: 259.5467 - mean_absolute_error: 13.0651 - val_loss: 201.6068 - val_mean_squared_error: 201.6068 - val_mean_absolute_error: 10.9825
# Epoch 13/1500
# 32/32 [==============================] - 1s - loss: 166.0001 - mean_squared_error: 166.0001 - mean_absolute_error: 11.2579 - val_loss: 173.6075 - val_mean_squared_error: 173.6075 - val_mean_absolute_error: 10.4074
# Epoch 14/1500
# 32/32 [==============================] - 1s - loss: 347.3329 - mean_squared_error: 347.3329 - mean_absolute_error: 15.1562 - val_loss: 430.8556 - val_mean_squared_error: 430.8556 - val_mean_absolute_error: 16.3645
# Epoch 15/1500
# 32/32 [==============================] - 1s - loss: 347.2685 - mean_squared_error: 347.2685 - mean_absolute_error: 14.6875 - val_loss: 209.5597 - val_mean_squared_error: 209.5597 - val_mean_absolute_error: 10.6720
# Epoch 16/1500
# 32/32 [==============================] - 1s - loss: 177.3179 - mean_squared_error: 177.3179 - mean_absolute_error: 10.3074 - val_loss: 234.1649 - val_mean_squared_error: 234.1649 - val_mean_absolute_error: 12.0835
# Epoch 17/1500
# 32/32 [==============================] - 1s - loss: 282.8168 - mean_squared_error: 282.8168 - mean_absolute_error: 13.0661 - val_loss: 217.2149 - val_mean_squared_error: 217.2149 - val_mean_absolute_error: 10.9732
# Epoch 18/1500
# 32/32 [==============================] - 1s - loss: 301.4821 - mean_squared_error: 301.4821 - mean_absolute_error: 12.2590 - val_loss: 135.3002 - val_mean_squared_error: 135.3002 - val_mean_absolute_error: 9.0825
# Epoch 19/1500
# 32/32 [==============================] - 1s - loss: 257.4803 - mean_squared_error: 257.4803 - mean_absolute_error: 11.8392 - val_loss: 320.7727 - val_mean_squared_error: 320.7727 - val_mean_absolute_error: 14.4942
# Epoch 20/1500
# 32/32 [==============================] - 1s - loss: 450.4883 - mean_squared_error: 450.4883 - mean_absolute_error: 15.3503 - val_loss: 513.8453 - val_mean_squared_error: 513.8453 - val_mean_absolute_error: 18.1366
# Epoch 21/1500
# 32/32 [==============================] - 1s - loss: 393.4436 - mean_squared_error: 393.4436 - mean_absolute_error: 14.0787 - val_loss: 228.4982 - val_mean_squared_error: 228.4982 - val_mean_absolute_error: 11.1306
# Epoch 22/1500
# 32/32 [==============================] - 1s - loss: 278.0633 - mean_squared_error: 278.0633 - mean_absolute_error: 12.2730 - val_loss: 348.7540 - val_mean_squared_error: 348.7540 - val_mean_absolute_error: 12.4375
# Epoch 23/1500
# 32/32 [==============================] - 1s - loss: 351.2948 - mean_squared_error: 351.2948 - mean_absolute_error: 13.6920 - val_loss: 193.2619 - val_mean_squared_error: 193.2619 - val_mean_absolute_error: 11.0070
# Epoch 24/1500
# 32/32 [==============================] - 1s - loss: 316.6440 - mean_squared_error: 316.6440 - mean_absolute_error: 13.1684 - val_loss: 310.2855 - val_mean_squared_error: 310.2855 - val_mean_absolute_error: 13.6250
# Epoch 25/1500
# 32/32 [==============================] - 1s - loss: 224.1949 - mean_squared_error: 224.1949 - mean_absolute_error: 11.4815 - val_loss: 242.9321 - val_mean_squared_error: 242.9321 - val_mean_absolute_error: 12.0043
# Epoch 26/1500
# 32/32 [==============================] - 1s - loss: 326.8696 - mean_squared_error: 326.8696 - mean_absolute_error: 14.1207 - val_loss: 247.5165 - val_mean_squared_error: 247.5165 - val_mean_absolute_error: 13.1947
# Epoch 27/1500
# 32/32 [==============================] - 1s - loss: 150.3266 - mean_squared_error: 150.3266 - mean_absolute_error: 9.9663 - val_loss: 279.9884 - val_mean_squared_error: 279.9884 - val_mean_absolute_error: 11.9206
# Epoch 28/1500
# 32/32 [==============================] - 1s - loss: 193.6175 - mean_squared_error: 193.6175 - mean_absolute_error: 11.6947 - val_loss: 189.3953 - val_mean_squared_error: 189.3953 - val_mean_absolute_error: 10.7047
# Epoch 29/1500
# 32/32 [==============================] - 1s - loss: 594.3986 - mean_squared_error: 594.3986 - mean_absolute_error: 18.4418 - val_loss: 323.0063 - val_mean_squared_error: 323.0063 - val_mean_absolute_error: 14.6231
# Epoch 30/1500
# 32/32 [==============================] - 1s - loss: 283.7666 - mean_squared_error: 283.7666 - mean_absolute_error: 12.4515 - val_loss: 233.5551 - val_mean_squared_error: 233.5551 - val_mean_absolute_error: 13.6591
# Epoch 163/1500
# 32/32 [==============================] - 1s - loss: 316.1626 - mean_squared_error: 316.1626 - mean_absolute_error: 15.8706 - val_loss: 394.4617 - val_mean_squared_error: 394.4617 - val_mean_absolute_error: 15.9199
# Epoch 164/1500
# 32/32 [==============================] - 1s - loss: 247.3568 - mean_squared_error: 247.3568 - mean_absolute_error: 13.3818 - val_loss: 303.3365 - val_mean_squared_error: 303.3365 - val_mean_absolute_error: 14.1266
# Epoch 165/1500
# 32/32 [==============================] - 1s - loss: 172.3282 - mean_squared_error: 172.3282 - mean_absolute_error: 11.5948 - val_loss: 220.9878 - val_mean_squared_error: 220.9878 - val_mean_absolute_error: 12.6686
# Epoch 166/1500
# 32/32 [==============================] - 1s - loss: 219.9170 - mean_squared_error: 219.9170 - mean_absolute_error: 13.7256 - val_loss: 386.0388 - val_mean_squared_error: 386.0388 - val_mean_absolute_error: 16.2599
# Epoch 167/1500
# 32/32 [==============================] - 1s - loss: 229.9899 - mean_squared_error: 229.9899 - mean_absolute_error: 12.3602 - val_loss: 382.7166 - val_mean_squared_error: 382.7166 - val_mean_absolute_error: 15.6218
# Epoch 168/1500
# 32/32 [==============================] - 1s - loss: 217.0845 - mean_squared_error: 217.0845 - mean_absolute_error: 12.4920 - val_loss: 199.9944 - val_mean_squared_error: 199.9944 - val_mean_absolute_error: 12.0665
# Epoch 169/1500
# 32/32 [==============================] - 1s - loss: 319.6845 - mean_squared_error: 319.6845 - mean_absolute_error: 14.6369 - val_loss: 194.9792 - val_mean_squared_error: 194.9792 - val_mean_absolute_error: 12.0490
# Epoch 170/1500
# 32/32 [==============================] - 1s - loss: 235.3740 - mean_squared_error: 235.3740 - mean_absolute_error: 13.2318 - val_loss: 280.1043 - val_mean_squared_error: 280.1043 - val_mean_absolute_error: 14.3877
# Epoch 171/1500
# 32/32 [==============================] - 1s - loss: 335.6076 - mean_squared_error: 335.6076 - mean_absolute_error: 13.8190 - val_loss: 200.0845 - val_mean_squared_error: 200.0845 - val_mean_absolute_error: 11.1045
# Epoch 172/1500
# 32/32 [==============================] - 1s - loss: 171.8428 - mean_squared_error: 171.8428 - mean_absolute_error: 11.6849 - val_loss: 196.0476 - val_mean_squared_error: 196.0476 - val_mean_absolute_error: 12.9637
# Epoch 173/1500
# 32/32 [==============================] - 1s - loss: 351.0178 - mean_squared_error: 351.0178 - mean_absolute_error: 16.2162 - val_loss: 246.0967 - val_mean_squared_error: 246.0967 - val_mean_absolute_error: 13.4232
# Epoch 174/1500
# 32/32 [==============================] - 1s - loss: 312.1199 - mean_squared_error: 312.1199 - mean_absolute_error: 13.9574 - val_loss: 218.4168 - val_mean_squared_error: 218.4168 - val_mean_absolute_error: 11.7124
# Epoch 175/1500
# 32/32 [==============================] - 1s - loss: 293.7571 - mean_squared_error: 293.7571 - mean_absolute_error: 13.4187 - val_loss: 256.4714 - val_mean_squared_error: 256.4714 - val_mean_absolute_error: 13.5575
# Epoch 176/1500
# Epoch 547/1500
# 32/32 [==============================] - 1s - loss: 303.2765 - mean_squared_error: 303.2765 - mean_absolute_error: 14.4063 - val_loss: 539.1700 - val_mean_squared_error: 539.1700 - val_mean_absolute_error: 18.1717
# Epoch 548/1500
# 32/32 [==============================] - 1s - loss: 294.8146 - mean_squared_error: 294.8146 - mean_absolute_error: 13.9535 - val_loss: 222.5042 - val_mean_squared_error: 222.5042 - val_mean_absolute_error: 13.5214
# Epoch 549/1500
# 32/32 [==============================] - 1s - loss: 314.8357 - mean_squared_error: 314.8357 - mean_absolute_error: 14.5921 - val_loss: 137.7518 - val_mean_squared_error: 137.7518 - val_mean_absolute_error: 10.6433
# Epoch 550/1500
# 32/32 [==============================] - 1s - loss: 272.0323 - mean_squared_error: 272.0323 - mean_absolute_error: 14.0059 - val_loss: 408.4992 - val_mean_squared_error: 408.4992 - val_mean_absolute_error: 15.6541
# Epoch 551/1500
# 32/32 [==============================] - 1s - loss: 274.3940 - mean_squared_error: 274.3940 - mean_absolute_error: 13.7629 - val_loss: 147.9708 - val_mean_squared_error: 147.9708 - val_mean_absolute_error: 9.5808
# Epoch 552/1500
# 32/32 [==============================] - 1s - loss: 459.7371 - mean_squared_error: 459.7371 - mean_absolute_error: 17.6898 - val_loss: 372.1774 - val_mean_squared_error: 372.1774 - val_mean_absolute_error: 16.0020
# Epoch 553/1500
# 32/32 [==============================] - 1s - loss: 256.2399 - mean_squared_error: 256.2399 - mean_absolute_error: 14.0645 - val_loss: 318.2812 - val_mean_squared_error: 318.2812 - val_mean_absolute_error: 14.3319
# Epoch 554/1500
# 32/32 [==============================] - 1s - loss: 255.7008 - mean_squared_error: 255.7008 - mean_absolute_error: 13.0506 - val_loss: 270.4747 - val_mean_squared_error: 270.4747 - val_mean_absolute_error: 13.2634
# Epoch 555/1500
# 32/32 [==============================] - 1s - loss: 360.0903 - mean_squared_error: 360.0903 - mean_absolute_error: 14.6607 - val_loss: 324.3329 - val_mean_squared_error: 324.3329 - val_mean_absolute_error: 15.0069
# Epoch 556/1500
# 32/32 [==============================] - 1s - loss: 279.5602 - mean_squared_error: 279.5602 - mean_absolute_error: 12.9962 - val_loss: 286.6571 - val_mean_squared_error: 286.6571 - val_mean_absolute_error: 14.0566
# Epoch 557/1500
# 32/32 [==============================] - 1s - loss: 192.6218 - mean_squared_error: 192.6218 - mean_absolute_error: 11.6680 - val_loss: 437.1559 - val_mean_squared_error: 437.1559 - val_mean_absolute_error: 16.4688
# Epoch 558/1500
# 32/32 [==============================] - 1s - loss: 165.6703 - mean_squared_error: 165.6703 - mean_absolute_error: 10.7683 - val_loss: 297.7274 - val_mean_squared_error: 297.7274 - val_mean_absolute_error: 14.7601
# Epoch 559/1500
# 32/32 [==============================] - 1s - loss: 252.9162 - mean_squared_error: 252.9162 - mean_absolute_error: 12.1239 - val_loss: 300.1768 - val_mean_squared_error: 300.1768 - val_mean_absolute_error: 13.9033
# Epoch 560/1500
# 32/32 [==============================] - 1s - loss: 247.6417 - mean_squared_error: 247.6417 - mean_absolute_error: 12.6562 - val_loss: 298.8234 - val_mean_squared_error: 298.8234 - val_mean_absolute_error: 14.3299
# Epoch 561/1500
# 32/32 [==============================] - 1s - loss: 183.9464 - mean_squared_error: 183.9464 - mean_absolute_error: 11.3510 - val_loss: 192.1992 - val_mean_squared_error: 192.1992 - val_mean_absolute_error: 11.7164
# Epoch 562/1500
# 32/32 [==============================] - 1s - loss: 306.6748 - mean_squared_error: 306.6748 - mean_absolute_error: 14.5650 - val_loss: 193.7535 - val_mean_squared_error: 193.7535 - val_mean_absolute_error: 11.8419
# Epoch 563/1500
# 32/32 [==============================] - 1s - loss: 259.2032 - mean_squared_error: 259.2032 - mean_absolute_error: 14.1837 - val_loss: 212.4449 - val_mean_squared_error: 212.4449 - val_mean_absolute_error: 13.4148
# Epoch 564/1500
# 32/32 [==============================] - 1s - loss: 336.6202 - mean_squared_error: 336.6202 - mean_absolute_error: 14.6648 - val_loss: 384.6835 - val_mean_squared_error: 384.6835 - val_mean_absolute_error: 14.5744
# Epoch 565/1500
# 32/32 [==============================] - 1s - loss: 251.1255 - mean_squared_error: 251.1255 - mean_absolute_error: 12.3970 - val_loss: 289.0784 - val_mean_squared_error: 289.0784 - val_mean_absolute_error: 13.9139
# Epoch 566/1500
# 32/32 [==============================] - 1s - loss: 351.9966 - mean_squared_error: 351.9966 - mean_absolute_error: 14.7418 - val_loss: 189.1407 - val_mean_squared_error: 189.1407 - val_mean_absolute_error: 11.5910
# Epoch 567/1500
# 32/32 [==============================] - 1s - loss: 249.7702 - mean_squared_error: 249.7702 - mean_absolute_error: 12.7734 - val_loss: 312.4322 - val_mean_squared_error: 312.4322 - val_mean_absolute_error: 15.4097
# Epoch 568/1500
# 32/32 [==============================] - 1s - loss: 192.8801 - mean_squared_error: 192.8801 - mean_absolute_error: 11.3297 - val_loss: 340.5274 - val_mean_squared_error: 340.5274 - val_mean_absolute_error: 13.8635
# Epoch 569/1500
# 32/32 [==============================] - 1s - loss: 172.7082 - mean_squared_error: 172.7082 - mean_absolute_error: 11.2993 - val_loss: 331.5826 - val_mean_squared_error: 331.5826 - val_mean_absolute_error: 14.7182
# Epoch 570/1500
# 32/32 [==============================] - 1s - loss: 193.5764 - mean_squared_error: 193.5764 - mean_absolute_error: 11.2797 - val_loss: 224.7639 - val_mean_squared_error: 224.7639 - val_mean_absolute_error: 11.5096
# Epoch 571/1500
# 32/32 [==============================] - 1s - loss: 233.1277 - mean_squared_error: 233.1277 - mean_absolute_error: 13.1958 - val_loss: 554.4303 - val_mean_squared_error: 554.4303 - val_mean_absolute_error: 18.8344
# Epoch 572/1500
# 32/32 [==============================] - 1s - loss: 291.3785 - mean_squared_error: 291.3785 - mean_absolute_error: 13.1188 - val_loss: 338.5022 - val_mean_squared_error: 338.5022 - val_mean_absolute_error: 13.6874
# Epoch 573/1500
# 32/32 [==============================] - 1s - loss: 318.2130 - mean_squared_error: 318.2130 - mean_absolute_error: 14.1875 - val_loss: 182.4955 - val_mean_squared_error: 182.4955 - val_mean_absolute_error: 11.5573
# Epoch 587/1500
# 32/32 [==============================] - 1s - loss: 350.9105 - mean_squared_error: 350.9105 - mean_absolute_error: 15.0287 - val_loss: 380.1303 - val_mean_squared_error: 380.1303 - val_mean_absolute_error: 17.1832
# Epoch 588/1500
# 32/32 [==============================] - 1s - loss: 351.1009 - mean_squared_error: 351.1009 - mean_absolute_error: 14.7770 - val_loss: 311.6999 - val_mean_squared_error: 311.6999 - val_mean_absolute_error: 14.5608
# Epoch 589/1500
# 32/32 [==============================] - 1s - loss: 177.0299 - mean_squared_error: 177.0299 - mean_absolute_error: 11.8322 - val_loss: 203.7305 - val_mean_squared_error: 203.7305 - val_mean_absolute_error: 11.2403
# Epoch 590/1500
# 32/32 [==============================] - 1s - loss: 281.9113 - mean_squared_error: 281.9113 - mean_absolute_error: 14.4879 - val_loss: 229.0331 - val_mean_squared_error: 229.0331 - val_mean_absolute_error: 13.0061
# Epoch 591/1500
# 32/32 [==============================] - 1s - loss: 336.3164 - mean_squared_error: 336.3164 - mean_absolute_error: 15.6875 - val_loss: 264.3835 - val_mean_squared_error: 264.3835 - val_mean_absolute_error: 13.9778
# Epoch 592/1500
# 32/32 [==============================] - 1s - loss: 413.8086 - mean_squared_error: 413.8086 - mean_absolute_error: 15.1365 - val_loss: 364.4266 - val_mean_squared_error: 364.4266 - val_mean_absolute_error: 15.4013
# Epoch 593/1500
# 32/32 [==============================] - 1s - loss: 268.9609 - mean_squared_error: 268.9609 - mean_absolute_error: 14.3294 - val_loss: 386.8803 - val_mean_squared_error: 386.8803 - val_mean_absolute_error: 15.6996
# Epoch 594/1500
# 32/32 [==============================] - 1s - loss: 196.6382 - mean_squared_error: 196.6382 - mean_absolute_error: 12.7493 - val_loss: 232.6041 - val_mean_squared_error: 232.6041 - val_mean_absolute_error: 13.5863
# Epoch 595/1500
# 32/32 [==============================] - 1s - loss: 212.5921 - mean_squared_error: 212.5921 - mean_absolute_error: 12.7098 - val_loss: 324.5087 - val_mean_squared_error: 324.5087 - val_mean_absolute_error: 15.0019
# Epoch 596/1500
# 32/32 [==============================] - 1s - loss: 195.6916 - mean_squared_error: 195.6916 - mean_absolute_error: 12.3159 - val_loss: 192.5663 - val_mean_squared_error: 192.5663 - val_mean_absolute_error: 12.3057
# Epoch 597/1500

# %% [markdown]
# ## 7. Evaluating the results

# %%
train_history = history.history['acc']
valid_history = history.history['val_acc']

# %%
 # Plotting training accuracy and testing accuracy acros epochs
plt.figure(figsize=(20,10))
plt.plot(train_history)
plt.plot(valid_history)
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig(PIC_NAME)

# %%
# Tail-rolling average transform
series_train = Series(train_history)
rolling_train = series_train.rolling(window=100)
rolling_mean_train = rolling_train.mean()

series_valid = Series(valid_history)
rolling_valid = series_valid.rolling(window=100)
rolling_mean_valid = rolling_valid.mean()

# %%
plt.figure(figsize=(20,10))
plt.plot(rolling_mean_train)
plt.plot(rolling_mean_valid)
plt.title('Smoothened training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Saving histories
np.save(TRA_HISTORY_NAME, train_history)
np.save(VAL_HISTORY_NAME, valid_history)

# %%
# saving weights
model.save_weights(WEIGHTS_NAME)

# %% [markdown]
# ### Results on Adience

# %%
model.evaluate_generator(adience_gender_test_gen,BATCH_SIZE*400)

# %%
raise EX

# %% [markdown]
# ## Finetuning with Adience

# %%
history = model.fit_generator(adience_gender_train_gen, 
                              validation_data=adience_gender_valid_gen,
                              nb_val_samples=BATCH_SIZE,
                              samples_per_epoch=BATCH_SIZE, 
                              nb_epoch=NUM_EPOCHS2)

# %%
train_history = history.history['acc']
valid_history = history.history['val_acc']

# %%
 # Plotting training accuracy and testing accuracy acros epochs
plt.figure(figsize=(20,10))
plt.plot(train_history)
plt.plot(valid_history)
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig(PIC_NAME_FINETUNING)

# %%
# Tail-rolling average transform
series_train = Series(train_history)
rolling_train = series_train.rolling(window=100)
rolling_mean_train = rolling_train.mean()

series_valid = Series(valid_history)
rolling_valid = series_valid.rolling(window=100)
rolling_mean_valid = rolling_valid.mean()

# %%
plt.figure(figsize=(20,10))
plt.plot(rolling_mean_train)
plt.plot(rolling_mean_valid)
plt.title('Smoothened training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Saving histories
np.save(TRA_HISTORY_NAME_FINETUNING, train_history)
np.save(VAL_HISTORY_NAME_FINETUNING, valid_history)

# %%
# saving weights
model.save_weights(WEIGHTS_NAME_FINETUNING)

# %%
model.evaluate_generator(adience_gender_test_gen,BATCH_SIZE*400)
