# %% [markdown]
# <center><h1>2. Vainilla CNNs</h1></center>

# %%
# Necessary modules
import pandas as pd
import numpy  as np

from keras.models     import Sequential
from keras.layers     import Dense, Dropout, Activation, Flatten
from keras.layers     import Convolution2D, MaxPooling2D
from keras.optimizers import SGD
from keras.layers.normalization import BatchNormalization

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using Theano backend.

# %%
# Get the data
data = pd.read_csv(filepath_or_buffer="../data/face_image_project/fold_0_data.txt", sep="\t")
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#         user_id                original_image  face_id       age gender     x  \
# 0  30601258@N03   8841797309_28a19a2461_o.jpg        2  (25, 32)      m   439
# 1  30601258@N03  10795391806_5398811a2f_o.jpg        4  (38, 43)      f  1576
# 2  10044155@N06  11331226025_e649b1c7cb_o.jpg      146  (48, 53)      m  1169
# 3  37303189@N08  11436877514_9b7e41c2b0_o.jpg       84    (0, 2)      m   303
# 4  20254529@N04   9404682034_1045946a18_o.jpg       14    (4, 6)      f   414
#
#       y   dx   dy  tilt_ang  fiducial_yaw_angle  fiducial_score
# 0   954  523  523       -95                   0             118
# 1  1101  580  580       155                   0              64
# 2   643  274  274         5                   0             118
# 3   514  444  444       -95                   0              36
# 4   338  728  622         0                   0              44

# %%
data = data[["user_id","original_image","face_id","gender"]]
data.head()
# Out:
#         user_id                original_image  face_id gender
# 0  30601258@N03   8841797309_28a19a2461_o.jpg        2      m
# 1  30601258@N03  10795391806_5398811a2f_o.jpg        4      f
# 2  10044155@N06  11331226025_e649b1c7cb_o.jpg      146      m
# 3  37303189@N08  11436877514_9b7e41c2b0_o.jpg       84      m
# 4  20254529@N04   9404682034_1045946a18_o.jpg       14      f

# %%
data.loc[data.gender != "m", "gender"] = 0
data.loc[data.gender == "m", "gender"] = 1
data.head()
# Out:
#         user_id                original_image  face_id gender
# 0  30601258@N03   8841797309_28a19a2461_o.jpg        2      1
# 1  30601258@N03  10795391806_5398811a2f_o.jpg        4      0
# 2  10044155@N06  11331226025_e649b1c7cb_o.jpg      146      1
# 3  37303189@N08  11436877514_9b7e41c2b0_o.jpg       84      1
# 4  20254529@N04   9404682034_1045946a18_o.jpg       14      0

# %%
path_template = "../data/face_image_project/aligned/%s/landmark_aligned_face.%d.%s"
data["file_path"] = data[["user_id","face_id","original_image"]].apply(lambda x:  
                                                                   path_template % (x[0],x[1],x[2]),
                                                                   axis=1)
data.head()
# Out:
#         user_id                original_image  face_id gender  \
# 0  30601258@N03   8841797309_28a19a2461_o.jpg        2      1
# 1  30601258@N03  10795391806_5398811a2f_o.jpg        4      0
# 2  10044155@N06  11331226025_e649b1c7cb_o.jpg      146      1
# 3  37303189@N08  11436877514_9b7e41c2b0_o.jpg       84      1
# 4  20254529@N04   9404682034_1045946a18_o.jpg       14      0
#
#                                            file_path
# 0  ../data/face_image_project/aligned/30601258@N0...
# 1  ../data/face_image_project/aligned/30601258@N0...
# 2  ../data/face_image_project/aligned/10044155@N0...
# 3  ../data/face_image_project/aligned/37303189@N0...
# 4  ../data/face_image_project/aligned/20254529@N0...

# %%
data = data[["file_path","gender"]]
data.head()
# Out:
#                                            file_path gender
# 0  ../data/face_image_project/aligned/30601258@N0...      1
# 1  ../data/face_image_project/aligned/30601258@N0...      0
# 2  ../data/face_image_project/aligned/10044155@N0...      1
# 3  ../data/face_image_project/aligned/37303189@N0...      1
# 4  ../data/face_image_project/aligned/20254529@N0...      0

# %%
data["gender"].value_counts()
# Out:
# 0    2437
# 1    2047
# Name: gender, dtype: int64

# %% [markdown]
# Occurences of each gender seem pretty balanced. Looks good to me

# %%
Y      = data["gender"]
X_path = data["file_path"]

# %%
X_path[0]
# Out:
# '../data/face_image_project/aligned/30601258@N03/landmark_aligned_face.2.8841797309_28a19a2461_o.jpg'

# %%
tempo = X_path[1:3]
tempo2 = tempo.apply(lambda x: img_to_array( load_img(x) ) ) #DOES IT NEED A RESHAPE
tempo
# Out:
# 1    ../data/face_image_project/aligned/30601258@N0...
# 2    ../data/face_image_project/aligned/10044155@N0...
# Name: file_path, dtype: object

# %%
import scipy.misc

i_width  = 227
i_height = 227

#scipy.misc.imresize(original_image, (i_height, i_width))


def train_generator(data):
    while True:
        start, end = 0, 32
        while end < len(data):
            data = data.sample(frac=1).reset_index(drop=True)
            sample  = data[start:end]

            X = pd.DataFrame(sample["file_path"].apply(lambda x:  img_to_array( scipy.misc.imresize(load_img(x), (i_height, i_width) ) ) ))
            
            X = X["file_path"].apply(lambda x: x.reshape((1,)+ x.shape))
            X = np.vstack(X)
            #print X[0].shape
            #print X.shape
            #
            Y = sample["gender"].as_matrix()
            #print Y.as_matrix()
            #print X.shape
            #print X
            yield (X, Y)
            start += 32
            end += 32

# %%
gen = train_generator(data)
a = gen.next()

# %%
# Building a vainilla CNN
vainilla_cnn = Sequential()
vainilla_cnn.add(Convolution2D(32, 3, 3, input_shape=(227,227,3)))
vainilla_cnn.add(Activation('relu'))
vainilla_cnn.add(MaxPooling2D(pool_size=(2, 2)))
vainilla_cnn.add(Convolution2D(64, 3, 3))
vainilla_cnn.add(Activation('relu'))
vainilla_cnn.add(Convolution2D(64, 3, 3))
vainilla_cnn.add(Activation('relu'))
vainilla_cnn.add(MaxPooling2D(pool_size=(2, 2)))
vainilla_cnn.add(Flatten())
vainilla_cnn.add(Dense(output_dim=200, input_dim=500))
vainilla_cnn.add(BatchNormalization())
vainilla_cnn.add(Activation("relu"))
vainilla_cnn.add(Dense(output_dim=100, input_dim=200))
vainilla_cnn.add(BatchNormalization())
vainilla_cnn.add(Activation("relu"))
vainilla_cnn.add(Dense(output_dim=1))
vainilla_cnn.add(Activation("sigmoid"))

# %%
# Compile
vainilla_cnn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train
vainilla_cnn.fit_generator(train_generator(data), samples_per_epoch=64, nb_epoch=200)
# Out:
# Epoch 1/200
# 64/64 [==============================] - 2s - loss: 0.8009 - acc: 0.5000
# Epoch 2/200
# 64/64 [==============================] - 1s - loss: 0.7826 - acc: 0.5625
# Epoch 3/200
# 64/64 [==============================] - 1s - loss: 0.7091 - acc: 0.6719
# Epoch 4/200
# 64/64 [==============================] - 1s - loss: 0.6683 - acc: 0.5938
# Epoch 5/200
# 64/64 [==============================] - 1s - loss: 0.5579 - acc: 0.7031
# Epoch 6/200
# Epoch 182/200
# 64/64 [==============================] - 1s - loss: 0.4113 - acc: 0.8125
# Epoch 183/200
# 64/64 [==============================] - 1s - loss: 0.3192 - acc: 0.8906
# Epoch 184/200
# 64/64 [==============================] - 1s - loss: 0.3445 - acc: 0.8906
# Epoch 185/200
# 64/64 [==============================] - 1s - loss: 0.2790 - acc: 0.8594
# Epoch 186/200
# 64/64 [==============================] - 1s - loss: 0.2243 - acc: 0.9219
# Epoch 187/200
# 64/64 [==============================] - 1s - loss: 0.3380 - acc: 0.8281
# Epoch 188/200
# 64/64 [==============================] - 1s - loss: 0.2885 - acc: 0.9375
# Epoch 189/200
# 64/64 [==============================] - 1s - loss: 0.3407 - acc: 0.8906
# Epoch 190/200
# 64/64 [==============================] - 1s - loss: 0.2906 - acc: 0.8750
# Epoch 191/200
# 64/64 [==============================] - 1s - loss: 0.3518 - acc: 0.8438
# Epoch 192/200
# 64/64 [==============================] - 1s - loss: 0.2649 - acc: 0.8594
# Epoch 193/200
# 64/64 [==============================] - 1s - loss: 0.2446 - acc: 0.9062
# Epoch 194/200
# 64/64 [==============================] - 1s - loss: 0.4041 - acc: 0.7656
# Epoch 195/200
# 64/64 [==============================] - 1s - loss: 0.3117 - acc: 0.8438
# Epoch 196/200
# 64/64 [==============================] - 1s - loss: 0.3659 - acc: 0.8594
# Epoch 197/200
# 64/64 [==============================] - 1s - loss: 0.2091 - acc: 0.9375
# Epoch 198/200
# 64/64 [==============================] - 1s - loss: 0.4510 - acc: 0.8281
# Epoch 199/200
# 64/64 [==============================] - 1s - loss: 0.2879 - acc: 0.8750
# Epoch 200/200
# 64/64 [==============================] - 1s - loss: 0.3405 - acc: 0.8750

# %%
# !nvidia-smi

# %%
def rowToImgPath(row):
    userid = row["user_id"]
    faceid = row["face_id"]
    original_img = row["original_image"]
    imgPath = "../data/face_image_project/aligned/%s/landmark_aligned_face.%d.%s" % (userid, faceid, original_img)
    return imgPath

def loadXY(data):
    """ BE INCREDIBLY CAREFUL... The data is large - you could run out of memory and start thrashing.
    It is highly advised to load a small subset at a time (100-200 rows)
    """ 
    X = np.zeros((len(data), 816, 816, 3))
    Y = data["gender"]
    for i in range(len(data)):
        row = data.iloc[i]
        img = load_img(rowToImgPath(row))
        imgArray = img_to_array(img)
        X[i] = imgArray
    return X, Y

def generateXY(data, size=5):
    """ From Keras fit_generator API: The generator is expected to loop over its data indefinitely. """
    while True:
        start, end = 0, size
        while end <= len(data):
            yield loadXY(data[start: end])
            start, end =  start + size, end + size

            
def loadXY2(data):
    """ BE INCREDIBLY CAREFUL... The data is large - you could run out of memory and start thrashing.
    It is highly advised to load a small subset at a time (100-200 rows)
    """ 
    X = np.zeros((len(data), 816, 816, 3))
    Y = data["gender"]
    for i in range(len(data)):
        row = data.iloc[i]
        img = load_img(rowToImgPath(row))
        imgArray = img_to_array(img)
        X[i] = imgArray
    return X, Y

def generateXY2(data, size=32):
    """ From Keras fit_generator API: The generator is expected to loop over its data indefinitely. """
    while True:
        start, end = 0, size
        while end <= len(data):
            yield loadXY(data[start: end])
            start, end =  start + size, end + size
