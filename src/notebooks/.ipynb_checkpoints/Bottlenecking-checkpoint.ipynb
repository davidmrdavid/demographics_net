# %%
from keras.engine import Input, Model
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.layers import Flatten, Dense, Dropout, BatchNormalization,  Activation, MaxPooling2D, ZeroPadding2D, Convolution2D
from vggface import VGGFace
from keras.models     import Sequential
import numpy as np
import keras
from keras.utils.data_utils import get_file

# %% [markdown]
# # Bottlenecking

# %%
nb_class = 3

image_input = Input(shape=(100, 100, 3))
vgg_model = VGGFace(input_tensor=image_input, include_top=False)
last_layer = vgg_model.get_layer('pool5').output

train_data_dir = "../data/face_image_project/keras_format/train"
datagen = ImageDataGenerator()
generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(100, 100),
        batch_size=3000,
        class_mode='categorical',  # this means our generator will only yield batches of data, no labels
        shuffle=True)  # our data will be in order, so all first 1000 images will be cats, then 1000 dogs
# the predict_generator method returns the output of a model, given
# a generator that yields batches of numpy data

X_train, Y_train = generator.next()


bottleneck_features_train = vgg_model.predict(X_train, 32)
#print bottleneck_features_train
# save the output as a Numpy array
np.save(open('bottleneck_features_train2.npy', 'w'), bottleneck_features_train)
# Out:
# K.image_dim_ordering: tf
# Found 14859 images belonging to 3 classes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-d817052307b3> in <module>()
#      16 # a generator that yields batches of numpy data
#      17
# ---> 18 X_train, Y_train = generator.next()
#      19
#      20
#
# /usr/local/lib/python2.7/dist-packages/Keras-1.2.0-py2.7.egg/keras/preprocessing/image.pyc in next(self)
#     691                            target_size=self.target_size)
#     692             x = img_to_array(img, dim_ordering=self.dim_ordering)
# --> 693             x = self.image_data_generator.random_transform(x)
#     694             x = self.image_data_generator.standardize(x)
#     695             batch_x[i] = x
#
# /usr/local/lib/python2.7/dist-packages/Keras-1.2.0-py2.7.egg/keras/preprocessing/image.pyc in random_transform(self, x)
#     401         transform_matrix = transform_matrix_offset_center(transform_matrix, h, w)
#     402         x = apply_transform(x, transform_matrix, img_channel_index,
# --> 403                             fill_mode=self.fill_mode, cval=self.cval)
#     404         if self.channel_shift_range != 0:
#     405             x = random_channel_shift(x, self.channel_shift_range, img_channel_index)
#
# /usr/local/lib/python2.7/dist-packages/Keras-1.2.0-py2.7.egg/keras/preprocessing/image.pyc in apply_transform(x, transform_matrix, channel_index, fill_mode, cval)
#     107     final_offset = transform_matrix[:2, 2]
#     108     channel_images = [ndi.interpolation.affine_transform(x_channel, final_affine_matrix,
# --> 109                       final_offset, order=0, mode=fill_mode, cval=cval) for x_channel in x]
#     110     x = np.stack(channel_images, axis=0)
#     111     x = np.rollaxis(x, 0, channel_index+1)
#
# /usr/local/lib/python2.7/dist-packages/scipy/ndimage/interpolation.pyc in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     436     else:
#     437         _geometric_transform(filtered, None, None, matrix, offset,
# --> 438                              output, order, mode, cval, None, None)
#     439     return return_value
#     440
#
# /usr/local/lib/python2.7/dist-packages/scipy/ndimage/interpolation.pyc in _geometric_transform(input, mapping, coordinates, matrix, offset, output, order, mode, cval, extra_arguments, extra_keywords)
#     130     _nd_image.geometric_transform(
#     131         input, mapping, coordinates, matrix, offset, output,
# --> 132         order, mode, cval, extra_arguments, extra_keywords)
#     133
#     134     if output is not None and not output.dtype.isnative:
#
# KeyboardInterrupt:

# %%
train_data = np.load(open('bottleneck_features_train2.npy'))

# Building a vainilla CNN
vainilla_cnn = Sequential()
vainilla_cnn.add(Flatten(input_shape=train_data.shape[1:]))
vainilla_cnn.add(Dense(output_dim=200))
vainilla_cnn.add(BatchNormalization())
vainilla_cnn.add(Activation("relu"))
vainilla_cnn.add(Dense(output_dim=100, input_dim=200))
vainilla_cnn.add(BatchNormalization())
vainilla_cnn.add(Activation("relu"))
vainilla_cnn.add(Dropout(0.5))
vainilla_cnn.add(Dense(output_dim=3))
vainilla_cnn.add(Activation("softmax"))

vainilla_cnn.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
vainilla_cnn.fit(train_data, Y_train,batch_size=32, nb_epoch=300)
# Out:
# Epoch 1/300
# 3000/3000 [==============================] - 1s - loss: 1.1683 - acc: 0.4723
# Epoch 2/300
#  - ETA: 0s - loss: 0.9025 - acc: 0.6094
# Epoch 3/300
# 3000/3000 [==============================] - 0s - loss: 0.7855 - acc: 0.6300
# Epoch 4/300
#  - ETA: 0s - loss: 0.7583 - acc: 0.6409
# Epoch 5/300
#  - ETA: 0s - loss: 0.6984 - acc: 0.6724
# Epoch 6/300
# 3000/3000 [==============================] - 0s - loss: 0.6427 - acc: 0.7017
# Epoch 7/300
#  - ETA: 0s - loss: 0.6289 - acc: 0.7188
# Epoch 8/300
# 3000/3000 [==============================] - 0s - loss: 0.5810 - acc: 0.7420
# Epoch 9/300
# 3000/3000 [==============================] - 0s - loss: 0.5634 - acc: 0.7477
# Epoch 10/300
#  - ETA: 0s - loss: 0.5229 - acc: 0.7711
# Epoch 11/300
# 3000/3000 [==============================] - 0s - loss: 0.4866 - acc: 0.7950
# Epoch 12/300
#  - ETA: 0s - loss: 0.4621 - acc: 0.8047
# Epoch 13/300
#  - ETA: 0s - loss: 0.4295 - acc: 0.8173
# Epoch 14/300
# 3000/3000 [==============================] - 0s - loss: 0.4377 - acc: 0.8093
# Epoch 15/300
# 3000/3000 [==============================] - 0s - loss: 0.3716 - acc: 0.8440
# Epoch 16/300
#  - ETA: 0s - loss: 0.3456 - acc: 0.8544
# Epoch 17/300
#  - ETA: 0s - loss: 0.3366 - acc: 0.8574
# Epoch 18/300
# 3000/3000 [==============================] - 0s - loss: 0.3335 - acc: 0.8570
# Epoch 19/300
# 3000/3000 [==============================] - 0s - loss: 0.3246 - acc: 0.8617
# Epoch 20/300
#  - ETA: 0s - loss: 0.2834 - acc: 0.8860
# Epoch 21/300
#  - ETA: 0s - loss: 0.2926 - acc: 0.8782
# Epoch 22/300
#  - ETA: 0s - loss: 0.2824 - acc: 0.8848
# Epoch 23/300
#  - ETA: 0s - loss: 0.2004 - acc: 0.9107
# Epoch 24/300
# 3000/3000 [==============================] - 0s - loss: 0.2651 - acc: 0.8913
# Epoch 25/300
#  - ETA: 0s - loss: 0.2477 - acc: 0.9112
# Epoch 26/300
# Epoch 274/300
#  - ETA: 0s - loss: 0.0089 - acc: 0.9984
# Epoch 275/300
# 3000/3000 [==============================] - 0s - loss: 0.0448 - acc: 0.9830
# Epoch 276/300
#  - ETA: 0s - loss: 0.0210 - acc: 0.9923
# Epoch 277/300
# 3000/3000 [==============================] - 0s - loss: 0.0475 - acc: 0.9850
# Epoch 278/300
#  - ETA: 0s - loss: 0.0404 - acc: 0.9828
# Epoch 279/300
#  - ETA: 0s - loss: 0.0254 - acc: 0.9925
# Epoch 280/300
#  - ETA: 0s - loss: 0.0263 - acc: 0.9866
# Epoch 281/300
#  - ETA: 0s - loss: 0.0459 - acc: 0.9808
# Epoch 282/300
#  - ETA: 0s - loss: 0.0107 - acc: 0.9980
# Epoch 283/300
#  - 0s - loss: 0.0192 - acc: 0.9920
# Epoch 284/300
# 3000/3000 [==============================] - 0s - loss: 0.0162 - acc: 0.9947
# Epoch 285/300
# 3000/3000 [==============================] - 0s - loss: 0.0795 - acc: 0.9750
# Epoch 286/300
#  - ETA: 0s - loss: 0.0348 - acc: 0.9893
# Epoch 287/300
#  - ETA: 0s - loss: 0.0744 - acc: 0.9722
# Epoch 288/300
#  - ETA: 0s - loss: 0.0411 - acc: 0.9812
# Epoch 289/300
#  - ETA: 0s - loss: 0.0135 - acc: 0.9957
# Epoch 290/300
# 3000/3000 [==============================] - 0s - loss: 0.0204 - acc: 0.9927
# Epoch 291/300
#  - ETA: 0s - loss: 0.0504 - acc: 0.9861
# Epoch 292/300
#  - ETA: 0s - loss: 0.0359 - acc: 0.9879
# Epoch 293/300
# 3000/3000 [==============================] - 0s - loss: 0.0382 - acc: 0.9883
# Epoch 294/300
# 3000/3000 [==============================] - 0s - loss: 0.0487 - acc: 0.9847
# Epoch 295/300
#  - ETA: 0s - loss: 0.0125 - acc: 0.9949
# Epoch 296/300
# 3000/3000 [==============================] - 0s - loss: 0.0210 - acc: 0.9950
# Epoch 297/300
# 3000/3000 [==============================] - 0s - loss: 0.0317 - acc: 0.9883
# Epoch 298/300
# 3000/3000 [==============================] - 0s - loss: 0.0397 - acc: 0.9890
# Epoch 299/300
# 3000/3000 [==============================] - 0s - loss: 0.0285 - acc: 0.9897
# Epoch 300/300
#  - ETA: 0s - loss: 0.0738 - acc: 0.9688

# %%
vainilla_cnn.save('saved')
vainilla_cnn.save_weights('my_model_weights.h5')

# %% [markdown]
# ## VGG-Face
# Source: https://github.com/rcmalli/keras-vggface

# %%
nb_class = 3
hidden_dim = 512
image_input = Input(shape=(200, 200, 3))
vgg_model = VGGFace(input_tensor=image_input, include_top=False)
last_layer = vgg_model.get_layer('pool5').output

x = Flatten(name='flatten')(last_layer)
x = Dense(hidden_dim, activation='relu', name='fc6')(x)
x = Dense(hidden_dim, activation='relu', name='fc7')(x)
out = Dense(nb_class, activation='softmax', name='fc8')(x)
custom_vgg_model = Model(image_input, out)

for layer in custom_vgg_model.layers[:25]:
    layer.trainable = False

custom_vgg_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# K.image_dim_ordering: tf

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img


img_height = 200
img_width  = 200
nb_epoch = 100
nb_train_samples = 32
nb_validation_samples = 32
train_data_dir = "../data/face_image_project/keras_format/train"
validation_data_dir ="../data/face_image_project/keras_format/test"

# prepare data augmentation configuration
train_datagen = ImageDataGenerator(
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_height, img_width),
        batch_size=32,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_height, img_width),
        batch_size=32,
        class_mode='categorical')

# fine-tune the model
history = custom_vgg_model.fit_generator(
        train_generator,
        samples_per_epoch=nb_train_samples,
        nb_epoch=nb_epoch,
        validation_data=validation_generator,
        nb_val_samples=nb_validation_samples)
# Out:
# Found 14859 images belonging to 3 classes.
# Found 3731 images belonging to 3 classes.
# Epoch 1/100
# 32/32 [==============================] - 12s - loss: 7.2795 - acc: 0.4688 - val_loss: 5.8062 - val_acc: 0.5625
# Epoch 2/100
# 32/32 [==============================] - 2s - loss: 6.3573 - acc: 0.5625 - val_loss: 8.4076 - val_acc: 0.4062
# Epoch 3/100
# 32/32 [==============================] - 2s - loss: 6.7158 - acc: 0.5625 - val_loss: 5.8607 - val_acc: 0.6250
# Epoch 4/100
# 32/32 [==============================] - 2s - loss: 8.4869 - acc: 0.4375 - val_loss: 7.9226 - val_acc: 0.4688
# Epoch 5/100
# 32/32 [==============================] - 2s - loss: 7.4777 - acc: 0.5000 - val_loss: 10.0078 - val_acc: 0.3750
# Epoch 6/100
# 32/32 [==============================] - 2s - loss: 7.6863 - acc: 0.5000 - val_loss: 6.4735 - val_acc: 0.5938
# Epoch 7/100
# 32/32 [==============================] - 2s - loss: 6.5480 - acc: 0.5938 - val_loss: 8.8007 - val_acc: 0.4062
# Epoch 8/100
# 32/32 [==============================] - 2s - loss: 8.2636 - acc: 0.4688 - val_loss: 6.2807 - val_acc: 0.5625
# Epoch 9/100
# 32/32 [==============================] - 2s - loss: 8.1594 - acc: 0.4375 - val_loss: 5.4053 - val_acc: 0.6562
# Epoch 10/100
# 32/32 [==============================] - 2s - loss: 10.4037 - acc: 0.3438 - val_loss: 5.3977 - val_acc: 0.6562
# Epoch 11/100
# 32/32 [==============================] - 2s - loss: 6.4870 - acc: 0.5938 - val_loss: 8.5349 - val_acc: 0.4375
# Epoch 12/100
# 32/32 [==============================] - 2s - loss: 8.1472 - acc: 0.4375 - val_loss: 9.5271 - val_acc: 0.3750
# Epoch 13/100
# 32/32 [==============================] - 2s - loss: 10.3997 - acc: 0.3438 - val_loss: 4.3444 - val_acc: 0.6875
# Epoch 14/100
# 32/32 [==============================] - 2s - loss: 5.3001 - acc: 0.6250 - val_loss: 10.7560 - val_acc: 0.2812
# Epoch 15/100
# 32/32 [==============================] - 2s - loss: 8.9045 - acc: 0.4062 - val_loss: 7.5664 - val_acc: 0.5000
# Epoch 16/100
# 32/32 [==============================] - 2s - loss: 3.9476 - acc: 0.7500 - val_loss: 6.3694 - val_acc: 0.5938
# Epoch 17/100
# 32/32 [==============================] - 2s - loss: 6.6557 - acc: 0.5625 - val_loss: 8.0279 - val_acc: 0.4375
# Epoch 84/100
# 32/32 [==============================] - 2s - loss: 6.1677 - acc: 0.5625 - val_loss: 6.2495 - val_acc: 0.5938
# Epoch 85/100
# 32/32 [==============================] - 2s - loss: 6.8581 - acc: 0.5625 - val_loss: 10.2070 - val_acc: 0.3125
# Epoch 86/100
# 32/32 [==============================] - 2s - loss: 5.9058 - acc: 0.6250 - val_loss: 9.3167 - val_acc: 0.4062
# Epoch 87/100
# 32/32 [==============================] - 2s - loss: 7.5628 - acc: 0.5000 - val_loss: 8.4014 - val_acc: 0.4688
# Epoch 88/100
# 32/32 [==============================] - 2s - loss: 6.9538 - acc: 0.5312 - val_loss: 8.4363 - val_acc: 0.4062
# Epoch 89/100
# 32/32 [==============================] - 2s - loss: 6.4563 - acc: 0.5938 - val_loss: 6.6144 - val_acc: 0.5000
# Epoch 90/100
# 32/32 [==============================] - 2s - loss: 7.5107 - acc: 0.4688 - val_loss: 6.1682 - val_acc: 0.5938
# Epoch 91/100
# 32/32 [==============================] - 2s - loss: 10.2240 - acc: 0.3125 - val_loss: 8.6880 - val_acc: 0.4375
# Epoch 92/100
# 32/32 [==============================] - 2s - loss: 7.5493 - acc: 0.4375 - val_loss: 6.1932 - val_acc: 0.5938
# Epoch 93/100
# 32/32 [==============================] - 2s - loss: 8.0084 - acc: 0.4375 - val_loss: 7.9407 - val_acc: 0.4688
# Epoch 94/100
# 32/32 [==============================] - 2s - loss: 8.3350 - acc: 0.4375 - val_loss: 9.0440 - val_acc: 0.4062
# Epoch 95/100
# 32/32 [==============================] - 2s - loss: 9.2390 - acc: 0.3750 - val_loss: 5.3578 - val_acc: 0.6562
# Epoch 96/100
# 32/32 [==============================] - 2s - loss: 7.3109 - acc: 0.5000 - val_loss: 5.4351 - val_acc: 0.6250
# Epoch 97/100
# 32/32 [==============================] - 2s - loss: 8.7200 - acc: 0.4375 - val_loss: 7.8910 - val_acc: 0.5000
# Epoch 98/100
# 32/32 [==============================] - 2s - loss: 5.8576 - acc: 0.6250 - val_loss: 9.3177 - val_acc: 0.3750
# Epoch 99/100
# 32/32 [==============================] - 2s - loss: 6.8466 - acc: 0.5000 - val_loss: 7.6433 - val_acc: 0.4688
# Epoch 100/100
# 32/32 [==============================] - 2s - loss: 7.3894 - acc: 0.4688 - val_loss: 5.9628 - val_acc: 0.5938

# %%
nb_class = 3
hidden_dim = 512
image_input = Input(shape=(200, 200, 3))
vgg_model = VGGFace(input_tensor=image_input, include_top=False)
last_layer = vgg_model.get_layer('pool5').output

x = Flatten(name='flatten')(last_layer)
x = Dense(hidden_dim, activation='relu', name='fc6')(x)
x = Dense(hidden_dim, activation='relu', name='fc7')(x)
out = Dense(nb_class, activation='softmax', name='fc8')(x)
custom_vgg_model = Model(image_input, out)

for layer in custom_vgg_model.layers[:20]:
    layer.trainable = False

custom_vgg_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# K.image_dim_ordering: tf

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img


img_height = 200
img_width  = 200
nb_epoch = 100
nb_train_samples = 32
nb_validation_samples = 32
train_data_dir = "../data/face_image_project/keras_format/train"
validation_data_dir ="../data/face_image_project/keras_format/test"

# prepare data augmentation configuration
train_datagen = ImageDataGenerator(
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_height, img_width),
        batch_size=32,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_height, img_width),
        batch_size=32,
        class_mode='categorical')

# fine-tune the model
history = custom_vgg_model.fit_generator(
        train_generator,
        samples_per_epoch=nb_train_samples,
        nb_epoch=nb_epoch,
        validation_data=validation_generator,
        nb_val_samples=nb_validation_samples)
# Out:
# Found 14859 images belonging to 3 classes.
# Found 3731 images belonging to 3 classes.
# Epoch 1/100
# 32/32 [==============================] - 3s - loss: 4.8237 - acc: 0.5625 - val_loss: 10.5775 - val_acc: 0.3438
# Epoch 2/100
# 32/32 [==============================] - 2s - loss: 12.0886 - acc: 0.2500 - val_loss: 10.0738 - val_acc: 0.3750
# Epoch 3/100
# 32/32 [==============================] - 2s - loss: 10.5775 - acc: 0.3438 - val_loss: 7.5554 - val_acc: 0.5312
# Epoch 4/100
# 32/32 [==============================] - 2s - loss: 10.5775 - acc: 0.3438 - val_loss: 9.0664 - val_acc: 0.4375
# Epoch 5/100
# 32/32 [==============================] - 2s - loss: 9.5701 - acc: 0.4062 - val_loss: 8.5627 - val_acc: 0.4688
# Epoch 6/100
# 32/32 [==============================] - 2s - loss: 9.5701 - acc: 0.4062 - val_loss: 8.5627 - val_acc: 0.4688
# Epoch 7/100
# 32/32 [==============================] - 2s - loss: 11.5849 - acc: 0.2812 - val_loss: 8.5627 - val_acc: 0.4688
# Epoch 8/100
# 32/32 [==============================] - 2s - loss: 6.5480 - acc: 0.5938 - val_loss: 10.5775 - val_acc: 0.3438
# Epoch 9/100
# 32/32 [==============================] - 2s - loss: 6.5480 - acc: 0.5938 - val_loss: 8.5627 - val_acc: 0.4688
# Epoch 10/100
# 32/32 [==============================] - 2s - loss: 9.5701 - acc: 0.4062 - val_loss: 9.5701 - val_acc: 0.4062
# Epoch 11/100
# 32/32 [==============================] - 2s - loss: 10.0738 - acc: 0.3750 - val_loss: 7.5554 - val_acc: 0.5312
# Epoch 12/100
# 32/32 [==============================] - 2s - loss: 7.5554 - acc: 0.5312 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 13/100
# 32/32 [==============================] - 2s - loss: 9.5701 - acc: 0.4062 - val_loss: 10.5775 - val_acc: 0.3438
# Epoch 14/100
# 32/32 [==============================] - 2s - loss: 8.5627 - acc: 0.4688 - val_loss: 9.0664 - val_acc: 0.4375
# Epoch 15/100
# 32/32 [==============================] - 2s - loss: 9.0664 - acc: 0.4375 - val_loss: 9.0664 - val_acc: 0.4375
# Epoch 16/100
# 32/32 [==============================] - 2s - loss: 9.5701 - acc: 0.4062 - val_loss: 10.5775 - val_acc: 0.3438
# Epoch 17/100
# 32/32 [==============================] - 2s - loss: 8.0590 - acc: 0.5000 - val_loss: 10.5775 - val_acc: 0.3438
# Epoch 18/100
# 32/32 [==============================] - 2s - loss: 8.0590 - acc: 0.5000 - val_loss: 9.0664 - val_acc: 0.4375
# Epoch 19/100
# 32/32 [==============================] - 2s - loss: 9.0664 - acc: 0.4375 - val_loss: 9.5701 - val_acc: 0.4062
- val_loss: 7.5554 - val_acc: 0.5312
# Epoch 88/100
# 32/32 [==============================] - 2s - loss: 6.5480 - acc: 0.5938 - val_loss: 7.5554 - val_acc: 0.5312
# Epoch 89/100
# 32/32 [==============================] - 2s - loss: 8.0590 - acc: 0.5000 - val_loss: 10.5775 - val_acc: 0.3438
# Epoch 90/100
# 32/32 [==============================] - 2s - loss: 10.5775 - acc: 0.3438 - val_loss: 10.0738 - val_acc: 0.3750
# Epoch 91/100
# 32/32 [==============================] - 2s - loss: 8.0590 - acc: 0.5000 - val_loss: 8.5627 - val_acc: 0.4688
# Epoch 92/100
# 32/32 [==============================] - 2s - loss: 7.0517 - acc: 0.5625 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 93/100
# 32/32 [==============================] - 2s - loss: 11.0812 - acc: 0.3125 - val_loss: 6.0443 - val_acc: 0.6250
# Epoch 94/100
# 32/32 [==============================] - 2s - loss: 8.0590 - acc: 0.5000 - val_loss: 7.0517 - val_acc: 0.5625
# Epoch 95/100
# 32/32 [==============================] - 2s - loss: 9.5701 - acc: 0.4062 - val_loss: 10.5775 - val_acc: 0.3438
# Epoch 96/100
# 32/32 [==============================] - 2s - loss: 8.5627 - acc: 0.4688 - val_loss: 9.0664 - val_acc: 0.4375
# Epoch 97/100
# 32/32 [==============================] - 2s - loss: 10.0738 - acc: 0.3750 - val_loss: 9.5701 - val_acc: 0.4062
# Epoch 98/100
# 32/32 [==============================] - 2s - loss: 10.5775 - acc: 0.3438 - val_loss: 8.5627 - val_acc: 0.4688
# Epoch 99/100
# 32/32 [==============================] - 2s - loss: 11.5849 - acc: 0.2812 - val_loss: 8.5627 - val_acc: 0.4688
# Epoch 100/100
# 32/32 [==============================] - 2s - loss: 9.5701 - acc: 0.4062 - val_loss: 8.0590 - val_acc: 0.5000

# %%
#nb_class = 3
#hidden_dim = 512
#image_input = Input(shape=(200, 200, 3))
#vgg_model = VGGFace(input_tensor=image_input, include_top=False)
#last_layer = vgg_model.get_layer('pool5').output

from keras.utils.data_utils import get_file
TF_WEIGHTS_PATH_NO_TOP = 'https://github.com/rcmalli/keras-vggface/releases/download/v1.0/rcmalli_vggface_tf_weights_tf_ordering_notop.h5'

img_width  = 224
img_height = 224

# build the VGG16 network
model = Sequential()

model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_1', input_shape=(img_width, img_height,3)))
model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_2'))
model.add(MaxPooling2D((2, 2), strides=(2, 2), dim_ordering="tf"))

model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_1'))
model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_2'))
model.add(MaxPooling2D((2, 2), strides=(2, 2),dim_ordering="tf"))

model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_1'))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_2'))
model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2),dim_ordering="tf"))

model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_1'))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_2'))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2),dim_ordering="tf"))

model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_1'))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_2'))
model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_3'))
model.add(MaxPooling2D((2, 2), strides=(2, 2),dim_ordering="tf"))

weights_path = get_file('rcmalli_vggface_tf_weights_tf_ordering_notop.h5',TF_WEIGHTS_PATH_NO_TOP,cache_subdir='models')
model.load_weights(weights_path)



top_model = Sequential()
top_model.add(Flatten(input_shape=model.output_shape[1:]))
top_model.add(Dense(output_dim=200))
top_model.add(BatchNormalization())
top_model.add(Activation("relu"))
top_model.add(Dense(output_dim=100, input_dim=200))
top_model.add(BatchNormalization())
top_model.add(Activation("relu"))
top_model.add(Dropout(0.5))
top_model.add(Dense(output_dim=3))
top_model.add(Activation("softmax"))

top_model.load_weights('my_model_weights.h5')
model.add(top_model)






#vainilla_cnn_pre_trained.compile
#vainilla_cnn_pre_trained.layers[0] = vainilla_cnn_pre_trained.layers[0](last_layer)
#out = vainilla_cnn_pre_trained.output
#ustom_vgg_model = Model(image_input, out)

#for layer in custom_vgg_model.layers[:25]:
#    layer.trainable = False
    

#custom_vgg_model.compile(loss='categorical_crossentropy', optimizer=optimizers.SGD(lr=1e-4, momentum=0.9), metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-915dea461d53> in <module>()
#      54 top_model.add(Activation("softmax"))
#      55
# ---> 56 top_model.load_weights('my_model_weights.h5')
#      57 model.add(top_model)
#      58
#
# /usr/local/lib/python2.7/dist-packages/Keras-1.2.0-py2.7.egg/keras/engine/topology.pyc in load_weights(self, filepath, by_name)
#    2699             self.load_weights_from_hdf5_group_by_name(f)
#    2700         else:
# -> 2701             self.load_weights_from_hdf5_group(f)
#    2702
#    2703         if hasattr(f, 'close'):
#
# /usr/local/lib/python2.7/dist-packages/Keras-1.2.0-py2.7.egg/keras/engine/topology.pyc in load_weights_from_hdf5_group(self, f)
#    2785                         weight_values[0] = w
#    2786                 weight_value_tuples += zip(symbolic_weights, weight_values)
# -> 2787             K.batch_set_value(weight_value_tuples)
#    2788
#    2789     def load_weights_from_hdf5_group_by_name(self, f):
#
# /usr/local/lib/python2.7/dist-packages/Keras-1.2.0-py2.7.egg/keras/backend/tensorflow_backend.pyc in batch_set_value(tuples)
#    1542                 assign_placeholder = tf.placeholder(tf_dtype,
#    1543                                                     shape=value.shape)
# -> 1544                 assign_op = x.assign(assign_placeholder)
#    1545                 x._assign_placeholder = assign_placeholder
#    1546                 x._assign_op = assign_op
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/variables.pyc in assign(self, value, use_locking)
#     573       the assignment has completed.
#     574     """
# --> 575     return state_ops.assign(self._variable, value, use_locking=use_locking)
#     576
#     577   def assign_add(self, delta, use_locking=False):
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/gen_state_ops.pyc in assign(ref, value, validate_shape, use_locking, name)
#      45   result = _op_def_lib.apply_op("Assign", ref=ref, value=value,
#      46                                 validate_shape=validate_shape,
# ---> 47                                 use_locking=use_locking, name=name)
#      48   return result
#      49
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.pyc in apply_op(self, op_type_name, name, **keywords)
#     757         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     758                          input_types=input_types, attrs=attr_protos,
# --> 759                          op_def=op_def)
#     760         if output_structure:
#     761           outputs = op.outputs
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2240                     original_op=self._default_original_op, op_def=op_def)
#    2241     if compute_shapes:
# -> 2242       set_shapes_for_outputs(ret)
#    2243     self._add_op(ret)
#    2244     self._record_op_seen_by_control_dependencies(ret)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in set_shapes_for_outputs(op)
#    1615       shape_func = _call_cpp_shape_fn_and_require_op
#    1616
# -> 1617   shapes = shape_func(op)
#    1618   if shapes is None:
#    1619     raise RuntimeError(
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/ops.pyc in call_with_requiring(op)
#    1566
#    1567   def call_with_requiring(op):
# -> 1568     return call_cpp_shape_fn(op, require_shape_fn=True)
#    1569
#    1570   _call_cpp_shape_fn_and_require_op = call_with_requiring
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/common_shapes.pyc in call_cpp_shape_fn(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     608     res = _call_cpp_shape_fn_impl(op, input_tensors_needed,
#     609                                   input_tensors_as_shapes_needed,
# --> 610                                   debug_python_shape_fn, require_shape_fn)
#     611     if not isinstance(res, dict):
#     612       # Handles the case where _call_cpp_shape_fn_impl calls unknown_shape(op).
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/common_shapes.pyc in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     673       missing_shape_fn = True
#     674     else:
# --> 675       raise ValueError(err.message)
#     676
#     677   if missing_shape_fn:
#
# ValueError: Dimension 0 in both shapes must be equal, but are 512 and 4608 for 'Assign_2022' (op: 'Assign') with input shapes: [512,200], [4608,200].

# %%
img_height = 200
img_width  = 200
nb_epoch = 100
nb_train_samples = 30
nb_validation_samples = 30
train_data_dir = "../data/face_image_project/keras_format/train"
validation_data_dir ="../data/face_image_project/keras_format/test"

# prepare data augmentation configuration
train_datagen = ImageDataGenerator(
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_height, img_width),
        batch_size=20,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_height, img_width),
        batch_size=10,
        class_mode='categorical')

# fine-tune the model
history = custom_vgg_model.fit_generator(
        train_generator,
        samples_per_epoch=nb_train_samples,
        nb_epoch=nb_epoch,
        validation_data=validation_generator,
        nb_val_samples=nb_validation_samples)
# Out:
# Found 14859 images belonging to 3 classes.
# Found 3731 images belonging to 3 classes.
# Epoch 1/100
# 40/30 [========================================] - 8s - loss: 1.7143 - acc: 0.3750 - val_loss: 1.4218 - val_acc: 0.4000
# Epoch 2/100
# 40/30 [========================================] - 2s - loss: 1.5173 - acc: 0.4250 - val_loss: 1.5761 - val_acc: 0.4000
# Epoch 3/100
# 40/30 [========================================] - 2s - loss: 1.3485 - acc: 0.4500 - val_loss: 1.1047 - val_acc: 0.6000
# Epoch 4/100
# 40/30 [========================================] - 2s - loss: 1.1728 - acc: 0.6000 - val_loss: 2.2383 - val_acc: 0.4333
# Epoch 5/100
# 40/30 [========================================] - 2s - loss: 1.3266 - acc: 0.4000 - val_loss: 1.7362 - val_acc: 0.5000
# Epoch 6/100
# 40/30 [========================================] - 2s - loss: 1.6207 - acc: 0.4000 - val_loss: 1.2641 - val_acc: 0.4333
# Epoch 7/100
# 40/30 [========================================] - 2s - loss: 1.3587 - acc: 0.5250 - val_loss: 1.1826 - val_acc: 0.3333
# Epoch 8/100
# 40/30 [========================================] - 2s - loss: 1.4710 - acc: 0.4500 - val_loss: 1.2807 - val_acc: 0.6333
# Epoch 9/100
# 40/30 [========================================] - 2s - loss: 1.0011 - acc: 0.5500 - val_loss: 1.9420 - val_acc: 0.4000
# Epoch 10/100
# 40/30 [========================================] - 2s - loss: 1.4732 - acc: 0.5000 - val_loss: 2.0393 - val_acc: 0.5000
# Epoch 11/100
# 40/30 [========================================] - 2s - loss: 1.1539 - acc: 0.4750 - val_loss: 3.3845 - val_acc: 0.2667
# Epoch 12/100
# 40/30 [========================================] - 2s - loss: 1.2659 - acc: 0.5000 - val_loss: 1.7596 - val_acc: 0.5667
# Epoch 57/100
# 40/30 [========================================] - 2s - loss: 1.2851 - acc: 0.4750 - val_loss: 1.2286 - val_acc: 0.6000
# Epoch 58/100
# 40/30 [========================================] - 2s - loss: 1.4909 - acc: 0.3750 - val_loss: 1.4484 - val_acc: 0.5333
# Epoch 59/100
# 40/30 [========================================] - 2s - loss: 0.7644 - acc: 0.6500 - val_loss: 0.7115 - val_acc: 0.7000
# Epoch 60/100
# 40/30 [========================================] - 2s - loss: 1.2165 - acc: 0.4750 - val_loss: 1.0663 - val_acc: 0.5333
# Epoch 61/100
# 40/30 [========================================] - 2s - loss: 0.9252 - acc: 0.6750 - val_loss: 1.6251 - val_acc: 0.3333
# Epoch 62/100
# 40/30 [========================================] - 2s - loss: 1.1518 - acc: 0.5750 - val_loss: 1.2478 - val_acc: 0.5000
# Epoch 63/100
# 40/30 [========================================] - 2s - loss: 0.7268 - acc: 0.7000 - val_loss: 1.1865 - val_acc: 0.5333
# Epoch 64/100
# 40/30 [========================================] - 2s - loss: 0.9101 - acc: 0.6000 - val_loss: 1.6767 - val_acc: 0.4667
# Epoch 65/100
# 40/30 [========================================] - 2s - loss: 1.6279 - acc: 0.5750 - val_loss: 1.3317 - val_acc: 0.5000
# Epoch 66/100
# 40/30 [========================================] - 2s - loss: 1.2306 - acc: 0.5750 - val_loss: 1.1301 - val_acc: 0.5333
# Epoch 67/100
# 40/30 [========================================] - 2s - loss: 1.4521 - acc: 0.4500 - val_loss: 1.1652 - val_acc: 0.5000
# Epoch 68/100
# 40/30 [========================================] - 2s - loss: 1.1449 - acc: 0.5000 - val_loss: 1.1213 - val_acc: 0.5000
# Epoch 69/100
# 40/30 [========================================] - 2s - loss: 1.1679 - acc: 0.5250 - val_loss: 1.2305 - val_acc: 0.4000
# Epoch 70/100
# 40/30 [========================================] - 2s - loss: 0.8357 - acc: 0.6000 - val_loss: 0.9768 - val_acc: 0.5333
# Epoch 71/100
# 40/30 [========================================] - 2s - loss: 1.0308 - acc: 0.5500 - val_loss: 1.2233 - val_acc: 0.5667
# Epoch 72/100
# 40/30 [========================================] - 2s - loss: 1.2115 - acc: 0.6000 - val_loss: 1.3954 - val_acc: 0.5667
# Epoch 73/100
# 40/30 [========================================] - 2s - loss: 1.0983 - acc: 0.5500 - val_loss: 1.2293 - val_acc: 0.5667
# Epoch 74/100
# 40/30 [========================================] - 2s - loss: 1.1106 - acc: 0.4750 - val_loss: 1.0396 - val_acc: 0.4000
# Epoch 75/100
# 40/30 [========================================] - 2s - loss: 1.2654 - acc: 0.5500 - val_loss: 0.9836 - val_acc: 0.5667
# Epoch 76/100
# 40/30 [========================================] - 2s - loss: 1.0206 - acc: 0.5250 - val_loss: 1.0955 - val_acc: 0.4667
# Epoch 77/100
# 40/30 [========================================] - 2s - loss: 0.8440 - acc: 0.7000 - val_loss: 1.2018 - val_acc: 0.4333
# Epoch 78/100
# 40/30 [========================================] - 2s - loss: 0.9660 - acc: 0.4750 - val_loss: 1.3925 - val_acc: 0.4333
# Epoch 79/100
# 40/30 [========================================] - 2s - loss: 1.0579 - acc: 0.5500 - val_loss: 1.5713 - val_acc: 0.3333
# Epoch 80/100
# 40/30 [========================================] - 2s - loss: 0.8382 - acc: 0.6000 - val_loss: 1.0516 - val_acc: 0.5333
# Epoch 81/100
# 40/30 [========================================] - 2s - loss: 1.5431 - acc: 0.4750 - val_loss: 0.9025 - val_acc: 0.6333
# Epoch 82/100
# 40/30 [========================================] - 2s - loss: 1.1092 - acc: 0.5500 - val_loss: 1.0813 - val_acc: 0.4333
# Epoch 83/100
# 40/30 [========================================] - 2s - loss: 0.9628 - acc: 0.6250 - val_loss: 1.0698 - val_acc: 0.3667
# Epoch 84/100
# 40/30 [========================================] - 2s - loss: 1.2738 - acc: 0.4250 - val_loss: 0.8489 - val_acc: 0.5667
# Epoch 85/100
# 40/30 [========================================] - 2s - loss: 1.1695 - acc: 0.5000 - val_loss: 1.0634 - val_acc: 0.4333
# Epoch 86/100
# 40/30 [========================================] - 2s - loss: 1.0557 - acc: 0.5000 - val_loss: 1.1816 - val_acc: 0.3667
# Epoch 87/100
# 40/30 [========================================] - 2s - loss: 1.2352 - acc: 0.5000 - val_loss: 0.8248 - val_acc: 0.6000
# Epoch 88/100
# 40/30 [========================================] - 2s - loss: 1.1100 - acc: 0.4750 - val_loss: 0.8759 - val_acc: 0.5667
# Epoch 89/100
# 40/30 [========================================] - 2s - loss: 1.2290 - acc: 0.4250 - val_loss: 0.8138 - val_acc: 0.6667
# Epoch 90/100
# 40/30 [========================================] - 2s - loss: 1.3256 - acc: 0.3250 - val_loss: 0.8779 - val_acc: 0.6333
# Epoch 91/100
# 40/30 [========================================] - 2s - loss: 0.8660 - acc: 0.7500 - val_loss: 0.7124 - val_acc: 0.6000
# Epoch 92/100
# 40/30 [========================================] - 2s - loss: 1.3263 - acc: 0.4250 - val_loss: 1.2216 - val_acc: 0.4333
# Epoch 93/100
# 40/30 [========================================] - 2s - loss: 1.1071 - acc: 0.5750 - val_loss: 0.8271 - val_acc: 0.5333
# Epoch 94/100
# 40/30 [========================================] - 2s - loss: 1.4923 - acc: 0.4750 - val_loss: 0.9516 - val_acc: 0.5333
# Epoch 95/100
# 40/30 [========================================] - 2s - loss: 1.1018 - acc: 0.6000 - val_loss: 0.6797 - val_acc: 0.6667
# Epoch 96/100
# 40/30 [========================================] - 2s - loss: 1.1192 - acc: 0.4500 - val_loss: 1.2944 - val_acc: 0.4000
# Epoch 97/100
# 40/30 [========================================] - 2s - loss: 0.9936 - acc: 0.4750 - val_loss: 1.3088 - val_acc: 0.5333
# Epoch 98/100
# 40/30 [========================================] - 2s - loss: 1.2772 - acc: 0.4500 - val_loss: 0.9702 - val_acc: 0.5333
# Epoch 99/100
# 40/30 [========================================] - 2s - loss: 1.0692 - acc: 0.4250 - val_loss: 1.0144 - val_acc: 0.5000
# Epoch 100/100
# 40/30 [========================================] - 2s - loss: 0.8869 - acc: 0.7000 - val_loss: 1.0425 - val_acc: 0.3333
